# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings(action="ignore")
import pandas_profiling

# %%
raw_data1 = pd.read_excel("./Data_Train.xlsx")
test_data = pd.read_excel("./Data_Test.xlsx")
raw_data1['source'] = 'train'
test_data['source'] = 'test'
raw_data = pd.concat([raw_data1,test_data],ignore_index=True)

# %%
raw_data1.head(8)
# Out:
#                                                Title  \
# 0                The Prisoner's Gold (The Hunters 3)
# 1                 Guru Dutt: A Tragedy in Three Acts
# 2                       Leviathan (Penguin Classics)
# 3                 A Pocket Full of Rye (Miss Marple)
# 4         LIFE 70 Years of Extraordinary Photography
# 5  ChiRunning: A Revolutionary Approach to Effort...
# 6                         Death on the Nile (Poirot)
# 7  Yoga Your Home Practice Companion: A Complete ...
#
#                           Author                         Edition  \
# 0                 Chris Kuzneski         Paperback,– 10 Mar 2016
# 1                   Arun Khopkar          Paperback,– 7 Nov 2012
# 2                  Thomas Hobbes         Paperback,– 25 Feb 1982
# 3                Agatha Christie          Paperback,– 5 Oct 2017
# 4                Editors of Life         Hardcover,– 10 Oct 2006
# 5                   Danny Dreyer          Paperback,– 5 May 2009
# 6                Agatha Christie          Paperback,– 5 Oct 2017
# 7  Sivananda Yoga Vedanta Centre  Hardcover,– Import, 1 Mar 2018
#
#               Reviews              Ratings  \
# 0  4.0 out of 5 stars   8 customer reviews
# 1  3.9 out of 5 stars  14 customer reviews
# 2  4.8 out of 5 stars   6 customer reviews
# 3  4.1 out of 5 stars  13 customer reviews
# 4  5.0 out of 5 stars    1 customer review
# 5  4.5 out of 5 stars   8 customer reviews
# 6  4.4 out of 5 stars  72 customer reviews
# 7  4.7 out of 5 stars  16 customer reviews
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
# 2  "During the time men live without a common Pow...
# 3  A handful of grain is found in the pocket of a...
# 4  For seven decades, "Life" has been thrilling t...
# 5  The revised edition of the bestselling ChiRunn...
# 6  Agatha Christie’s most exotic murder mystery\n...
# 7  Achieve a healthy body, mental alertness, and ...
#
#                                 Genre                          BookCategory  \
# 0          Action & Adventure (Books)                    Action & Adventure
# 1          Cinema & Broadcast (Books)  Biographies, Diaries & True Accounts
# 2             International Relations                                Humour
# 3        Contemporary Fiction (Books)             Crime, Thriller & Mystery
# 4               Photography Textbooks              Arts, Film & Photography
# 5   Healthy Living & Wellness (Books)                                Sports
# 6   Crime, Thriller & Mystery (Books)             Crime, Thriller & Mystery
# 7  Sports Training & Coaching (Books)                                Sports
#
#     Price source
# 0  220.00  train
# 1  202.93  train
# 2  299.00  train
# 3  180.00  train
# 4  965.62  train
# 5  900.00  train
# 6  224.00  train
# 7  836.00  train

# %%
print("The train shape is", raw_data1.shape)
print("The test shape is", test_data.shape)
print("The combined shape is", raw_data.shape)
# Out:
# The train shape is (6237, 10)
# The test shape is (1560, 9)
# The combined shape is (7797, 10)

# %%
pandas_profiling.ProfileReport(raw_data1)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>10 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>6237 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>487.3 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>80.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>8 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Author"><code>Author</code></a> has a high cardinality: 3679 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Edition"><code>Edition</code></a> has a high cardinality: 3370 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Genre"><code>Genre</code></a> has a high cardinality: 345 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Ratings"><code>Ratings</code></a> has a high cardinality: 342 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Synopsis"><code>Synopsis</code></a> has a high cardinality: 5549 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Title"><code>Title</code></a> has a high cardinality: 5568 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_source"><code>source</code></a> has constant value train <span class="label label-primary">Rejected</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p c

# %%
pandas_profiling.ProfileReport(test_data)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>9 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>1560 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>109.8 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>72.1 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>8 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Author"><code>Author</code></a> has a high cardinality: 1224 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Edition"><code>Edition</code></a> has a high cardinality: 1259 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Genre"><code>Genre</code></a> has a high cardinality: 225 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Ratings"><code>Ratings</code></a> has a high cardinality: 163 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Synopsis"><code>Synopsis</code></a> has a high cardinality: 1519 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Title"><code>Title</code></a> has a high cardinality: 1521 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_source"><code>source</code></a> has constant value test <span class="label label-primary">Rejected</span></li><li>Dataset has 8 duplicate rows <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </di

# %%
pandas_profiling.ProfileReport(raw_data)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>10 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>7797 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>2.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>609.2 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>80.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>9 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Author"><code>Author</code></a> has a high cardinality: 4372 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Edition"><code>Edition</code></a> has a high cardinality: 3882 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Genre"><code>Genre</code></a> has a high cardinality: 363 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Price"><code>Price</code></a> has 1560 / 20.0% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Ratings"><code>Ratings</code></a> has a high cardinality: 368 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Synopsis"><code>Synopsis</code></a> has a high cardinality: 6771 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Title"><code>Title</code></a> has a high cardinality: 6787 distinct values  <span class="label label-warning">Warning</span></li><li>Dataset has 8 duplicate rows <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>

# %% [markdown]
# ### Hypothesis on <b>Title and Author</b> features
#
# 1. The book names are unique, so dropping them at this point
# 2. Let us label encode the author names.

# %%
raw_data1.drop(['Title'], axis=1, inplace=True)
test_data.drop(['Title'], axis=1, inplace=True)
raw_data.drop(['Title'], axis=1, inplace=True)

# %% [markdown]
# ## Let us split edition into the type of book and the publication date
#
# #### We are doing the following to split the Edition into the publication type and its date. First, I am making sure there are no leading/tracing spaces:
#
# ## raw_data1['Edition'] = raw_data1['Edition'].str.strip()
#
# #### Then, I am extracting the Publication type.  What the Regex does is to look for one or more non-digit characters. So once it hits the first digit it stops and thus gives me the name:
#
# ## raw_data1['Edition'].str.extract('(\D+)', expand=False)
#
# #### To separate the the date/year of publication, I am using the same functionality. But here I am looking for the first digit to appear and any following character.
#
# ## raw_data1['Edition'].str.extract('(\d+.*)', expand=False)</p>

# %%
raw_data1['Edition'] = raw_data1['Edition'].str.strip()
raw_data1['Publication_Type']=raw_data1['Edition'].str.extract('(\D+)', expand=False)
raw_data1['Publication_Date'] = raw_data1['Edition'].str.extract('(\d+.*)', expand=False)
raw_data1['Publication_Type']=raw_data1['Publication_Type'].str.replace('\,–',"")
raw_data1['Publication_Type']=raw_data1['Publication_Type'].str.replace('\,',"")

# %%
raw_data['Edition'] = raw_data['Edition'].str.strip()
raw_data['Publication_Type']=raw_data['Edition'].str.extract('(\D+)', expand=False)
raw_data['Publication_Date'] = raw_data['Edition'].str.extract('(\d+.*)', expand=False)
raw_data['Publication_Type']=raw_data['Publication_Type'].str.replace('\,–',"")
raw_data['Publication_Type']=raw_data['Publication_Type'].str.replace('\,',"")

# %%
test_data['Edition'] = test_data['Edition'].str.strip()
test_data['Publication_Type']=test_data['Edition'].str.extract('(\D+)', expand=False)
test_data['Publication_Date'] = test_data['Edition'].str.extract('(\d+.*)', expand=False)
test_data['Publication_Type']=test_data['Publication_Type'].str.replace('\,–',"")
test_data['Publication_Type']=test_data['Publication_Type'].str.replace('\,',"")

# %%
raw_data1['Publication_Type'].value_counts()
# Out:
# Paperback                                    4490
# Hardcover                                     691
# Paperback Import                              502
# Mass Market Paperback                         142
# Hardcover Import                               88
# Paperback Illustrated                          27
# Hardcover Illustrated                          18
# Paperback Unabridged                           17
# Sheet music                                    14
# Paperback Special Edition                      14
# Flexibound                                     14
# Paperback Student Edition                      13
# Paperback May                                  12
# Mass Market Paperback Import                   10
# Paperback International Edition                10
# Paperback Nov                                  10
# Sheet music Import                             10
# Paperback Jan                                   9
# Paperback Box set                               8
# Paperback Aug                                   7
# Cards                                           7
# Paperback Abridged                              6
# Paperback Jun                                   5
# Paperback Deckle Edge                           5
# Paperback Sep                                   5
# Paperback Dec                                   5
# Paperback Jul                                   5
# Paperback Oct                                   5
# Paperback Illustrated Import                    4
# Spiral-bound                                    4
#                                              ...
# Hardcover Audiobook Unabridged                  1
# (Spanish)Paperback Import                       1
# Perfect Paperback                               1
# Library Binding                                 1
# Paperback Abridged Import                       1
# Mass Market Paperback Large Print               1
# Board book                                      1
# Paperback Illustrated Large Print               1
# Paperback Student Edition Special Edition       1
# (French)Paperback                               1
# Paperback EveryBook                             1
# Paperback Print Jun                             1
# Hardcover Large Print                           1
# Hardcover Abridged Audiobook Box set            1
# Flexibound Import                               1
# Paperback Box set Aug                           1
# Hardcover Unabridged                            1
# Mass Market Paperback Abridged                  1
# Tankobon Softcover Apr                          1
# Hardcover Import Facsimile                      1
# Paperback ADPCM                                 1
# Mass Market Paperback Print                     1
# Hardcover Facsimile Import                      1
# Hardcover Import Jan                            1
# (Kannada)Paperback                              1
# Product Bundle                                  1
# Hardcover Jun                                   1
# Plastic Comb DVD NTSC                           1
# Tankobon Softcover                              1
# Paperback Kindle eBook                          1
# Name: Publication_Type, Length: 85, dtype: int64

# %%
raw_data1['Publication_Type']=raw_data1['Publication_Type'].str.replace('Jan','').str.strip()
raw_data1['Publication_Type']=raw_data1['Publication_Type'].str.replace('Feb','').str.strip()
raw_data1['Publication_Type']=raw_data1['Publication_Type'].str.replace('Mar','').str.strip()
raw_data1['Publication_Type']=raw_data1['Publication_Type'].str.replace('Apr','').str.strip()
raw_data1['Publication_Type']=raw_data1['Publication_Type'].str.replace('May','').str.strip()
raw_data1['Publication_Type']=raw_data1['Publication_Type'].str.replace('Jun','').str.strip()
raw_data1['Publication_Type']=raw_data1['Publication_Type'].str.replace('Jul','').str.strip()
raw_data1['Publication_Type']=raw_data1['Publication_Type'].str.replace('Aug','').str.strip()
raw_data1['Publication_Type']=raw_data1['Publication_Type'].str.replace('Sep','').str.strip()
raw_data1['Publication_Type']=raw_data1['Publication_Type'].str.replace('Oct','').str.strip()
raw_data1['Publication_Type']=raw_data1['Publication_Type'].str.replace('Nov','').str.strip()
raw_data1['Publication_Type']=raw_data1['Publication_Type'].str.replace('Dec','').str.strip()

# %%
raw_data1['Publication_Type'].value_counts()
# Out:
# Paperback                                    4562
# Hardcover                                     697
# Paperback Import                              502
# Mass ket Paperback                            142
# Hardcover Import                               89
# Paperback Illustrated                          27
# Hardcover Illustrated                          18
# Paperback Unabridged                           17
# Flexibound                                     14
# Paperback Special Edition                      14
# Sheet music                                    14
# Paperback Student Edition                      13
# Paperback International Edition                10
# Mass ket Paperback Import                      10
# Sheet music Import                             10
# Paperback Box set                               9
# Cards                                           7
# Paperback Abridged                              6
# Paperback kle Edge                              5
# Paperback Large Print                           4
# Paperback Illustrated Import                    4
# Paperback Abridged Audiobook Box set            4
# Hardcover Special Edition                       4
# Spiral-bound                                    4
# Paperback Audiobook                             3
# Hardcover Facsimile                             2
# Paperback Print                                 2
# Hardcover Box set                               2
# Tankobon Softcover                              2
# Paperback Large Print Import                    2
#                                              ...
# Paperback Illustrated Large Print               1
# Product Bundle                                  1
# Hardcover Import Facsimile                      1
# Perfect Paperback                               1
# Flexibound Import                               1
# Library Binding                                 1
# (French)Paperback                               1
# Paperback ADPCM                                 1
# Hardcover Audiobook Unabridged                  1
# Cards Illustrated                               1
# Paperback Abridged Import                       1
# (German)Paperback                               1
# (Kannada)Paperback                              1
# Mass ket Paperback Large Print                  1
# Hardcover Deluxe Edition                        1
# Mass ket Paperback Print                        1
# Paperback Kindle eBook                          1
# Paperback Bargain Price                         1
# Hardcover Facsimile Import                      1
# Hardcover Abridged                              1
# Hardcover Large Print                           1
# Hardcover Abridged Audiobook Box set            1
# Paperback EveryBook                             1
# Plastic Comb DVD NTSC                           1
# Board book                                      1
# Leather Bound Import                            1
# Paperback Student Edition Special Edition       1
# Tankobon Softcover Import                       1
# Paperback Abridged Audiobook Large Print        1
# Hardcover Illustrated Import                    1
# Name: Publication_Type, Length: 66, dtype: int64

# %%
def mapping(df,col,n=25):
 print(col,n)
 vc = df[col].value_counts()
 replacements = {}
 for col, s in vc.items():
    print(col,s)
    if s<n:
        replacements[col] = 'other'
 return replacements

# %%
Pub_type_replace = mapping(raw_data1,'Publication_Type',9)
# Out:
# Publication_Type 9
# Paperback 4562
# Hardcover 697
# Paperback Import 502
# Mass ket Paperback 142
# Hardcover Import 89
# Paperback Illustrated 27
# Hardcover Illustrated 18
# Paperback Unabridged 17
# Flexibound 14
# Paperback Special Edition 14
# Sheet music 14
# Paperback Student Edition 13
# Paperback International Edition 10
# Mass ket Paperback Import 10
# Sheet music Import 10
# Paperback Box set 9
# Cards 7
# Paperback Abridged 6
# Paperback kle Edge 5
# Paperback Large Print 4
# Paperback Illustrated Import 4
# Paperback Abridged Audiobook Box set 4
# Hardcover Special Edition 4
# Spiral-bound 4
# Paperback Audiobook 3
# Hardcover Facsimile 2
# Paperback Print 2
# Hardcover Box set 2
# Tankobon Softcover 2
# Paperback Large Print Import 2
# Loose Leaf 2
# Hardcover kle Edge 2
# Hardcover Unabridged 1
# Mass ket Paperback Abridged 1
# (Spanish)Paperback Import 1
# Paperback Illustrated Large Print Audiobook 1
# Paperback Illustrated Large Print 1
# Product Bundle 1
# Hardcover Import Facsimile 1
# Perfect Paperback 1
# Flexibound Import 1
# Library Binding 1
# (French)Paperback 1
# Paperback ADPCM 1
# Hardcover Audiobook Unabridged 1
# Cards Illustrated 1
# Paperback Abridged Import 1
# (German)Paperback 1
# (Kannada)Paperback 1
# Mass ket Paperback Large Print 1
# Hardcover Deluxe Edition 1
# Mass ket Paperback Print 1
# Paperback Kindle eBook 1
# Paperback Bargain Price 1
# Hardcover Facsimile Import 1
# Hardcover Abridged 1
# Hardcover Large Print 1
# Hardcover Abridged Audiobook Box set 1
# Paperback EveryBook 1
# Plastic Comb DVD NTSC 1
# Board book 1
# Leather Bound Import 1
# Paperback Student Edition Special Edition 1
# Tankobon Softcover Import 1
# Paperback Abridged Audiobook Large Print 1
# Hardcover Illustrated Import 1

# %%
raw_data1['Publication_Type'] = raw_data1['Publication_Type'].replace(Pub_type_replace)

# %%
raw_data1['Publication_Type'].value_counts()
# Out:
# Paperback                          4562
# Hardcover                           697
# Paperback Import                    502
# Mass ket Paperback                  142
# other                                89
# Hardcover Import                     89
# Paperback Illustrated                27
# Hardcover Illustrated                18
# Paperback Unabridged                 17
# Sheet music                          14
# Flexibound                           14
# Paperback Special Edition            14
# Paperback Student Edition            13
# Paperback International Edition      10
# Sheet music Import                   10
# Mass ket Paperback Import            10
# Paperback Box set                     9
# Name: Publication_Type, dtype: int64

# %%
raw_data1['Publication_Date'] = pd.to_datetime(raw_data1['Publication_Date'])
raw_data1['Publication_Year'] = pd.DatetimeIndex(raw_data1['Publication_Date']).year
raw_data1['Publication_Month'] = pd.DatetimeIndex(raw_data1['Publication_Date']).month
raw_data1.drop(['Edition','Publication_Date'], axis=1, inplace=True)

# %%
raw_data1.head(5)
# Out:
#             Author             Reviews              Ratings  \
# 0   Chris Kuzneski  4.0 out of 5 stars   8 customer reviews
# 1     Arun Khopkar  3.9 out of 5 stars  14 customer reviews
# 2    Thomas Hobbes  4.8 out of 5 stars   6 customer reviews
# 3  Agatha Christie  4.1 out of 5 stars  13 customer reviews
# 4  Editors of Life  5.0 out of 5 stars    1 customer review
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
# 2  "During the time men live without a common Pow...
# 3  A handful of grain is found in the pocket of a...
# 4  For seven decades, "Life" has been thrilling t...
#
#                           Genre                          BookCategory   Price  \
# 0    Action & Adventure (Books)                    Action & Adventure  220.00
# 1    Cinema & Broadcast (Books)  Biographies, Diaries & True Accounts  202.93
# 2       International Relations                                Humour  299.00
# 3  Contemporary Fiction (Books)             Crime, Thriller & Mystery  180.00
# 4         Photography Textbooks              Arts, Film & Photography  965.62
#
#   source Publication_Type  Publication_Year  Publication_Month
# 0  train        Paperback            2016.0                3.0
# 1  train        Paperback            2012.0               11.0
# 2  train        Paperback            1982.0                2.0
# 3  train        Paperback            2017.0               10.0
# 4  train        Hardcover            2006.0               10.0

# %% [markdown]
# ## Converting Ratings and Reviews column to numeric

# %%
raw_data1['Reviews'] = raw_data1['Reviews'].str.replace("out of 5 stars",'').str.strip()
raw_data1['Ratings'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
raw_data1['Reviews'] = pd.to_numeric(raw_data1['Reviews'])
raw_data1['Ratings'] = pd.to_numeric(raw_data1['Ratings'])

# %%
raw_data1.head(5)
# Out:
#             Author  Reviews  Ratings  \
# 0   Chris Kuzneski      4.0        8
# 1     Arun Khopkar      3.9       14
# 2    Thomas Hobbes      4.8        6
# 3  Agatha Christie      4.1       13
# 4  Editors of Life      5.0        1
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
# 2  "During the time men live without a common Pow...
# 3  A handful of grain is found in the pocket of a...
# 4  For seven decades, "Life" has been thrilling t...
#
#                           Genre                          BookCategory   Price  \
# 0    Action & Adventure (Books)                    Action & Adventure  220.00
# 1    Cinema & Broadcast (Books)  Biographies, Diaries & True Accounts  202.93
# 2       International Relations                                Humour  299.00
# 3  Contemporary Fiction (Books)             Crime, Thriller & Mystery  180.00
# 4         Photography Textbooks              Arts, Film & Photography  965.62
#
#   source Publication_Type  Publication_Year  Publication_Month
# 0  train        Paperback            2016.0                3.0
# 1  train        Paperback            2012.0               11.0
# 2  train        Paperback            1982.0                2.0
# 3  train        Paperback            2017.0               10.0
# 4  train        Hardcover            2006.0               10.0

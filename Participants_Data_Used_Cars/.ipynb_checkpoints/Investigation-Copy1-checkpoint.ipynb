# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings(action="ignore")
import pandas_profiling

# %%
raw_data1 = pd.read_excel("./Data_Train.xlsx")
test_data = pd.read_excel("./Data_Test.xlsx")
raw_data1['source'] = 'train'
test_data['source'] = 'test'
raw_data = pd.concat([raw_data1,test_data],ignore_index=True)

# %%
raw_data1
# Out:
#                                                   Name    Location  Year  \
# 0                               Maruti Wagon R LXI CNG      Mumbai  2010
# 1                     Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                         Honda Jazz V     Chennai  2011
# 3                                    Maruti Ertiga VDI     Chennai  2012
# 4                      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 5                      Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6                               Nissan Micra Diesel XV      Jaipur  2013
# 7                    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 8                  Volkswagen Vento Diesel Comfortline        Pune  2013
# 9                       Tata Indica Vista Quadrajet LS     Chennai  2012
# 10                                    Maruti Ciaz Zeta       Kochi  2018
# 11                         Honda City 1.5 V AT Sunroof     Kolkata  2012
# 12                               Maruti Swift VDI BSIV      Jaipur  2015
# 13                    Land Rover Range Rover 2.2L Pure       Delhi  2014
# 14                      Land Rover Freelander 2 TD4 SE        Pune  2012
# 15                         Mitsubishi Pajero Sport 4X4       Delhi  2014
# 16                               Honda Amaze S i-Dtech       Kochi  2016
# 17                               Maruti Swift DDiS VDI      Jaipur  2017
# 18                 Renault Duster 85PS Diesel RxL Plus       Kochi  2014
# 19    Mercedes-Benz New C-Class C 220 CDI BE Avantgare   Bangalore  2014
# 20                                   BMW 3 Series 320d       Kochi  2014
# 21                       Maruti S Cross DDiS 200 Alpha   Bangalore  2015
# 22                Audi A6 2011-2015 35 TFSI Technology      Mumbai  2015
# 23                               Hyundai i20 1.2 Magna     Kolkata  2010
# 24                 Volkswagen Vento Petrol Highline AT     Kolkata  2010
# 25                        Honda City Corporate Edition      Mumbai  2012
# 26                              Nissan Micra Diesel XV   Hyderabad  2012
# 27                       Maruti Alto K10 2010-2014 VXI   Hyderabad  2013
# 28                                 Honda WRV i-VTEC VX       Kochi  2018
# 29                 Toyota Innova 2.5 V Diesel 7-seater      Mumbai  2007
# ...                                                ...         ...   ...
# 5989                       Audi A4 35 TDI Premium Plus  Coimbatore  2013
# 5990                  Tata New Safari DICOR 2.2 VX 4x2        Pune  2008
# 5991                                  Maruti Swift VDI   Hyderabad  2012
# 5992                  Skoda Superb Elegance 1.8 TSI AT      Mumbai  2011
# 5993                                Hyundai Elantra SX      Mumbai  2014
# 5994                               Honda City 1.5 E MT        Pune  2009
# 5995            Renault Duster 85PS Diesel RxL Explore        Pune  2015
# 5996                        Jaguar XF 2.2 Litre Luxury       Kochi  2016
# 5997                            Maruti Wagon R Duo Lxi      Jaipur  2010
# 5998        Volkswagen Polo IPL II 1.2 Petrol Highline        Pune  2010
# 5999                             Tata Bolt Revotron XT     Chennai  2016
# 6000                            Hyundai i20 Sportz 1.2   Bangalore  2014
# 6001                         Audi A6 2011-2015 2.0 TDI       Kochi  2013
# 6002                     Volkswagen Vento 1.6 Highline      Mumbai  2011
# 6003                                Maruti Celerio VXI   Bangalore  2015
# 6004                                  Hyundai Getz GLE  Coimbatore  2007
# 6005                          Maruti Vitara Brezza VDi        Pune  2016
# 6006                  Mercedes-Benz M-Class ML 320 CDI      Mumbai  2009
# 6007                       Maruti Swift Dzire Vdi BSIV       Delhi  2011
# 6008                           Porsche Panamera Diesel   Hyderabad  2013
# 6009                               Toyota Camry Hybrid      Mumbai  2015
# 6010                              Honda Brio 1.2 VX MT       Delhi  2013
# 6011                           Skoda Superb 3.6 V6 FSI   Hyderabad  2009
# 6012               Toyota Innova 2.5 V Diesel 7-seater  Coimbatore  2011
# 6013                             Honda Amaze VX i-DTEC  Coimbatore  2015
# 6014                                  Maruti Swift VDI       Delhi  2014
# 6015                          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016                             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017                                Maruti Wagon R VXI     Kolkata  2013
# 6018                             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission      Owner_Type     Mileage  \
# 0                 72000       CNG       Manual           First  26.6 km/kg
# 1                 41000    Diesel       Manual           First  19.67 kmpl
# 2                 46000    Petrol       Manual           First   18.2 kmpl
# 3                 87000    Diesel       Manual           First  20.77 kmpl
# 4                 40670    Diesel    Automatic          Second   15.2 kmpl
# 5                 75000       LPG       Manual           First  21.1 km/kg
# 6                 86999    Diesel       Manual           First  23.08 kmpl
# 7                 36000    Diesel    Automatic           First  11.36 kmpl
# 8                 64430    Diesel       Manual           First  20.54 kmpl
# 9                 65932    Diesel       Manual          Second   22.3 kmpl
# 10                25692    Petrol       Manual           First  21.56 kmpl
# 11                60000    Petrol    Automatic           First   16.8 kmpl
# 12                64424    Diesel       Manual           First   25.2 kmpl
# 13                72000    Diesel    Automatic           First   12.7 kmpl
# 14                85000    Diesel    Automatic          Second    0.0 kmpl
# 15               110000    Diesel       Manual           First   13.5 kmpl
# 16                58950    Diesel       Manual           First   25.8 kmpl
# 17                25000    Diesel       Manual           First   28.4 kmpl
# 18                77469    Diesel       Manual           First  20.45 kmpl
# 19                78500    Diesel    Automatic           First  14.84 kmpl
# 20                32982    Diesel    Automatic           First  22.69 kmpl
# 21                55392    Diesel       Manual          Second  23.65 kmpl
# 22                55985    Petrol    Automatic           First  13.53 kmpl
# 23                45807    Petrol       Manual           First   18.5 kmpl
# 24                33000    Petrol    Automatic           First   14.4 kmpl
# 25                51920    Petrol       Manual           First   16.8 kmpl
# 26                54000    Diesel       Manual           First  23.08 kmpl
# 27                54000    Petrol       Manual          Second  20.92 kmpl
# 28                37430    Petrol       Manual           First   17.5 kmpl
# 29               262000    Diesel       Manual  Fourth & Above   12.8 kmpl
# ...                 ...       ...          ...             ...         ...
# 5989              58629    Diesel    Automatic          Second  18.25 kmpl
# 5990              86000    Diesel       Manual           Third  13.93 kmpl
# 5991              68238    Diesel       Manual           First   22.9 kmpl
# 5992              42036    Petrol    Automatic           First   13.7 kmpl
# 5993              55619    Petrol       Manual           First   16.3 kmpl
# 5994              60000    Petrol       Manual           Third   17.0 kmpl
# 5995              30000    Diesel       Manual           First  19.87 kmpl
# 5996              31150    Diesel    Automatic           First  16.36 kmpl
# 5997              70000       LPG       Manual           First  26.2 km/kg
# 5998              70290    Petrol       Manual          Second  17.24 kmpl
# 5999              10000    Petrol       Manual           First  17.57 kmpl
# 6000              68010    Petrol       Manual          Second   18.5 kmpl
# 6001              91903    Diesel    Automatic           First  17.68 kmpl
# 6002              38000    Petrol       Manual           First  16.09 kmpl
# 6003              67600    Petrol       Manual           First   23.1 kmpl
# 6004              66800    Petrol       Manual           First   15.3 kmpl
# 6005              37208    Diesel       Manual           First   24.3 kmpl
# 6006             102002    Diesel    Automatic           First    8.7 kmpl
# 6007              68000    Diesel       Manual           First   19.3 kmpl
# 6008              40000    Diesel    Automatic          Second  17.85 kmpl
# 6009              33500    Petrol    Automatic           First  19.16 kmpl
# 6010              33746    Petrol       Manual           First   18.5 kmpl
# 6011              53000    Petrol    Automatic           First    0.0 kmpl
# 6012              45004    Diesel       Manual           First   12.8 kmpl
# 6013              70602    Diesel       Manual           First   25.8 kmpl
# 6014              27365    Diesel       Manual           First   28.4 kmpl
# 6015             100000    Diesel       Manual           First   24.4 kmpl
# 6016              55000    Diesel       Manual          Second   14.0 kmpl
# 6017              46000    Petrol       Manual           First   18.9 kmpl
# 6018              47000    Diesel       Manual           First  25.44 kmpl
#
#        Engine       Power  Seats   New_Price  Price source
# 0      998 CC   58.16 bhp    5.0         NaN   1.75  train
# 1     1582 CC   126.2 bhp    5.0         NaN  12.50  train
# 2     1199 CC    88.7 bhp    5.0   8.61 Lakh   4.50  train
# 3     1248 CC   88.76 bhp    7.0         NaN   6.00  train
# 4     1968 CC   140.8 bhp    5.0         NaN  17.74  train
# 5      814 CC    55.2 bhp    5.0         NaN   2.35  train
# 6     1461 CC    63.1 bhp    5.0         NaN   3.50  train
# 7     2755 CC   171.5 bhp    8.0     21 Lakh  17.50  train
# 8     1598 CC   103.6 bhp    5.0         NaN   5.20  train
# 9     1248 CC      74 bhp    5.0         NaN   1.95  train
# 10    1462 CC  103.25 bhp    5.0  10.65 Lakh   9.95  train
# 11    1497 CC   116.3 bhp    5.0         NaN   4.49  train
# 12    1248 CC      74 bhp    5.0         NaN   5.60  train
# 13    2179 CC   187.7 bhp    5.0         NaN  27.00  train
# 14    2179 CC     115 bhp    5.0         NaN  17.50  train
# 15    2477 CC  175.56 bhp    7.0  32.01 Lakh  15.00  train
# 16    1498 CC    98.6 bhp    5.0         NaN   5.40  train
# 17    1248 CC      74 bhp    5.0         NaN   5.99  train
# 18    1461 CC    83.8 bhp    5.0         NaN   6.34  train
# 19    2143 CC  167.62 bhp    5.0         NaN  28.00  train
# 20    1995 CC     190 bhp    5.0  47.87 Lakh  18.55  train
# 21    1248 CC    88.5 bhp    5.0         NaN   8.25  train
# 22    1984 CC  177.01 bhp    5.0         NaN  23.50  train
# 23    1197 CC      80 bhp    5.0         NaN   1.87  train
# 24    1598 CC   103.6 bhp    5.0         NaN   2.85  train
# 25    1497 CC   116.3 bhp    5.0         NaN   4.25  train
# 26    1461 CC    63.1 bhp    5.0         NaN   4.25  train
# 27     998 CC    67.1 bhp    5.0         NaN   2.75  train
# 28    1199 CC    88.7 bhp    5.0  10.57 Lakh   9.90  train
# 29    2494 CC     102 bhp    7.0         NaN   4.00  train
# ...       ...         ...    ...         ...    ...    ...
# 5989  1968 CC  187.74 bhp    5.0  53.14 Lakh  16.52  train
# 5990  2179 CC     138 bhp    7.0         NaN   0.60  train
# 5991  1248 CC      74 bhp    5.0         NaN   4.80  train
# 5992  1798 CC  157.75 bhp    5.0         NaN   6.25  train
# 5993  1797 CC   147.5 bhp    5.0         NaN   8.30  train
# 5994  1497 CC     118 bhp    5.0         NaN   3.25  train
# 5995  1461 CC    83.8 bhp    5.0         NaN   7.75  train
# 5996  2179 CC   187.7 bhp    5.0         NaN  30.54  train
# 5997   998 CC    58.2 bhp    5.0         NaN   2.27  train
# 5998  1198 CC    73.9 bhp    5.0         NaN   2.96  train
# 5999  1193 CC    88.7 bhp    5.0   7.77 Lakh   4.00  train
# 6000  1197 CC   82.85 bhp    5.0         NaN   5.25  train
# 6001  1968 CC  174.33 bhp    5.0         NaN  17.56  train
# 6002  1598 CC   103.5 bhp    5.0  11.91 Lakh   3.25  train
# 6003   998 CC   67.04 bhp    5.0         NaN   4.00  train
# 6004  1341 CC      83 bhp    5.0         NaN   2.20  train
# 6005  1248 CC    88.5 bhp    5.0   9.93 Lakh   7.43  train
# 6006  2987 CC  224.34 bhp    5.0         NaN  10.75  train
# 6007  1248 CC    73.9 bhp    5.0         NaN   2.75  train
# 6008  2967 CC     300 bhp    4.0         NaN  45.00  train
# 6009  2494 CC   158.2 bhp    5.0         NaN  19.75  train
# 6010  1198 CC    86.8 bhp    5.0   6.63 Lakh   3.20  train
# 6011  3597 CC   262.6 bhp    5.0         NaN   4.75  train
# 6012  2494 CC     102 bhp    7.0         NaN   9.48  train
# 6013  1498 CC    98.6 bhp    5.0         NaN   4.83  train
# 6014  1248 CC      74 bhp    5.0   7.88 Lakh   4.75  train
# 6015  1120 CC      71 bhp    5.0         NaN   4.00  train
# 6016  2498 CC     112 bhp    8.0         NaN   2.90  train
# 6017   998 CC    67.1 bhp    5.0         NaN   2.65  train
# 6018   936 CC    57.6 bhp    5.0         NaN   2.50  train
#
# [6019 rows x 14 columns]

# %%
print("The train shape is", raw_data1.shape)
print("The test shape is", test_data.shape)
# Out:
# The train shape is (6019, 14)
# The test shape is (1234, 13)

# %%
pandas_profiling.ProfileReport(raw_data1)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>14 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>6019 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>6.3% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>658.4 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>112.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>9 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Engine"><code>Engine</code></a> has a high cardinality: 147 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Kilometers_Driven"><code>Kilometers_Driven</code></a> is highly skewed (γ1 = 58.725)  <span class="label label-info">Skewed</span></li><li><a href="#pp_var_Mileage"><code>Mileage</code></a> has a high cardinality: 443 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Name"><code>Name</code></a> has a high cardinality: 1876 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_New_Price"><code>New_Price</code></a> has 5195 / 86.3% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_New_Price"><code>New_Price</code></a> has a high cardinality: 541 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Power"><code>Power</code></a> has a high cardinality: 373 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_source"><code>source</code></a> has constant value train <span class="label label-primary">Rejected</span></li> </ul>
#     </div>
# </div>
#     <div class="

# %%
pandas_profiling.ProfileReport(raw_data)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>14 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>7253 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>7.5% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>793.4 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>112.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>10 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Engine"><code>Engine</code></a> has a high cardinality: 151 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Kilometers_Driven"><code>Kilometers_Driven</code></a> is highly skewed (γ1 = 61.583)  <span class="label label-info">Skewed</span></li><li><a href="#pp_var_Mileage"><code>Mileage</code></a> has a high cardinality: 451 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Name"><code>Name</code></a> has a high cardinality: 2041 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_New_Price"><code>New_Price</code></a> has 6247 / 86.1% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_New_Price"><code>New_Price</code></a> has a high cardinality: 626 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Power"><code>Power</code></a> has a high cardinality: 387 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Price"><code>Price</code></a> has 1234 / 17.0% missing values <span class="label label-default">Missing</span></li><li>Dataset has 1 duplicate rows <sp

# %% [markdown]
# # Intial Investigation results and next steps !!

# %% [markdown]
# ### 1. Name : -
#       The name of the car is having a high cardinality, the next step here is to extract brand/manfratrer.
#
# ### 2. Kilometers_Driven: -
#        Highly skewed feature, next steps pending...
#
# ### 3. Mileage : -
#        Convert this field to numeric and investigate there are some values which are seen to have a value 0, 0 milage for a car sounds bad data.
#
# ### 4. Engine CC :-
#         We can bucket this feature, the steps to bucketing still not decided.
#
# ### 5. Power : -
#        Convert this field to numeric and investigate.
#
# ### 6. New_price : -
#        This feature has 86% missing values, at this point this feature will be elminated.
#
# ### 7. Price : -
#        Check website for the units for this independent feature.
#
# ### 8. Location/Transmission/Owner_type/Seats : -
#        These are all categoric variables.
#
# ### 9. Year : -
#        Investigate if this is the year the car was sold or bought.

# %% [markdown]
# ###  Let us begin by converting the Mileage and Power feature

# %%
raw_data['Power'].isnull().sum()
# Out:
# 46

# %%
raw_data['Power'].fillna('0xgb', inplace=True)

# %%
raw_data['Power'].isnull().sum()
# Out:
# 0

# %%
raw_data['Mileage']=raw_data['Mileage'].str.replace('[^\d.]','').astype(float)
raw_data['Power']=raw_data['Power'].str.replace('[^\d.]','')

# %%
raw_data['Power'].isnull().sum()
# Out:
# 0

# %%
#raw_data['Mileage'].replace(regex=True,inplace=True,to_replace=r'\D.\D',value=r'')
#raw_data['Power'].replace(regex=True,inplace=True,to_replace=r'\D.\D',value=r'')

# %%
#raw_data["Mileage"] = pd.to_numeric(raw_data["Mileage"])
raw_data["Power"] = pd.to_numeric(raw_data["Power"])

# %% [markdown]
# ### NOTE AFTER CONVERTING THE COLUMN TO NUMERIC WE HAVE 129 nan values in POWER column,should think what needs to be done here

# %%
raw_data['Power'].isnull().sum()
# Out:
# 129

# %%
raw_data['Power'].fillna(0, inplace=True)

# %%
raw_data['Power'].isnull().sum()
# Out:
# 0

# %%
pandas_profiling.ProfileReport(raw_data[['Mileage','Power']])
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>7253 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>113.4 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>16.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Mileage"><code>Mileage</code></a> has 81 / 1.1% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Power"><code>Power</code></a> has 175 / 2.4% zeros <span class="label label-info">Zeros</span></li><li>Dataset has 6275 duplicate rows <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Mileage">Mileage<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>
#                     <td>439</td>
#                 </tr>
#                 <tr>
#                     <th>Unique (%)</th>
#                     <td>6.1%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (n)</th>
#                     <td>2</td>

# %%
sns.distplot(np.log(raw_data1['Price'] * 100000))

# %%
pandas_profiling.ProfileReport(raw_data1[['Price']] * 100000 )
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>6019 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>47.1 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>8.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li>Dataset has 4646 duplicate rows <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Price">Price<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>
#                     <td
# 7233                                    Audi A4 2.0 TDI         NaN
# 7234                      Hyundai Verna 1.6 SX VTVT (O)         NaN
# 7235                           Maruti Vitara Brezza ZDi  10.57 Lakh
# 7236                       Hyundai Elite i20 Magna Plus   7.08 Lakh
# 7237                              Honda Amaze S i-Dtech         NaN
# 7238                                    Audi A4 2.0 TDI         NaN
# 7239                          Honda Amaze VX AT i-Vtech         NaN
# 7240                            Honda Jazz 1.5 V i DTEC         NaN
# 7241                            BMW 5 Series 525d Sedan         NaN
# 7242                      Hyundai Grand i10 Asta Option         NaN
# 7243                     Renault Duster 85PS Diesel RxL         NaN
# 7244                              Chevrolet Aveo 1.4 LS         NaN
# 7245                              Honda Amaze S i-Vtech         NaN
# 7246                          Hyundai Grand i10 AT Asta         NaN
# 7247                            Hyundai EON D Lite Plus         NaN
# 7248                  Volkswagen Vento Diesel Trendline         NaN
# 7249                             Volkswagen Polo GT TSI         NaN
# 7250                             Nissan Micra Diesel XV         NaN
# 7251                             Volkswagen Polo GT TSI         NaN
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...         NaN
#
#           Owner_Type   Power  Price  Seats Transmission  Year source
# 0              First   58.16   1.75    5.0       Manual  2010  train
# 1              First  126.20  12.50    5.0       Manual  2015  train
# 2              First   88.70   4.50    5.0       Manual  2011  train
# 3              First   88.76   6.00    7.0       Manual  2012  train
# 4             Second  140.80  17.74    5.0    Automatic  2013  train
# 5              First   55.20   2.35    5.0       Manual  2012  train
# 6              First   63.10   3.50    5.0       Manual  2013  train
# 7              First  171.50  17.50    8.0    Automatic  2016  train
# 8              First  103.60   5.20    5.0       Manual  2013  train
# 9             Second   74.00   1.95    5.0       Manual  2012  train
# 10             First  103.25   9.95    5.0       Manual  2018  train
# 11             First  116.30   4.49    5.0    Automatic  2012  train
# 12             First   74.00   5.60    5.0       Manual  2015  train
# 13             First  187.70  27.00    5.0    Automatic  2014  train
# 14            Second  115.00  17.50    5.0    Automatic  2012  train
# 15             First  175.56  15.00    7.0       Manual  2014  train
# 16             First   98.60   5.40    5.0       Manual  2016  train
# 17             First   74.00   5.99    5.0       Manual  2017  train
# 18             First   83.80   6.34    5.0       Manual  2014  train
# 19             First  167.62  28.00    5.0    Automatic  2014  train
# 20             First  190.00  18.55    5.0    Automatic  2014  train
# 21            Second   88.50   8.25    5.0       Manual  2015  train
# 22             First  177.01  23.50    5.0    Automatic  2015  train
# 23             First   80.00   1.87    5.0       Manual  2010  train
# 24             First  103.60   2.85    5.0    Automatic  2010  train
# 25             First  116.30   4.25    5.0       Manual  2012  train
# 26             First   63.10   4.25    5.0       Manual  2012  train
# 27            Second   67.10   2.75    5.0       Manual  2013  train
# 28             First   88.70   9.90    5.0       Manual  2018  train
# 29    Fourth & Above  102.00   4.00    7.0       Manual  2007  train
# ...              ...     ...    ...    ...          ...   ...    ...
# 7223           First  147.90    NaN    7.0       Manual  2011   test
# 7224           First   67.00    NaN    5.0       Manual  2016   test
# 7225           First  157.80    NaN    5.0       Manual  2010   test
# 7226           First   62.00    NaN    5.0       Manual  2014   test
# 7227          Second   65.00    NaN    5.0       Manual  2007   test
# 7228           First   69.00    NaN    5.0       Manual  2016   test
# 7229          Second  103.60    NaN    5.0    Automatic  2011   test
# 7230           First   81.83    NaN    5.0       Manual  2014   test
# 7231           First  121.36    NaN    5.0       Manual  2017   test
# 7232           First  160.00    NaN    5.0       Manual  2018   test
# 7233           First  147.51    NaN    5.0    Automatic  2014   test
# 7234           First  121.30    NaN    5.0       Manual  2013   test
# 7235           First   88.50    NaN    5.0       Manual  2017   test
# 7236           First   81.86    NaN    5.0       Manual  2018   test
# 7237           First   98.60    NaN    5.0       Manual  2013   test
# 7238           First  147.51    NaN    5.0    Automatic  2011   test
# 7239           First   86.70    NaN    5.0    Automatic  2014   test
# 7240           First   98.60    NaN    5.0       Manual  2017   test
# 7241           First  218.00    NaN    5.0    Automatic  2012   test
# 7242           First   82.00    NaN    5.0       Manual  2015   test
# 7243           First   83.80    NaN    5.0       Manual  2015   test
# 7244           First   92.70    NaN    5.0       Manual  2009   test
# 7245           First   86.70    NaN    5.0       Manual  2015   test
# 7246           First   82.00    NaN    5.0    Automatic  2016   test
# 7247           First   55.20    NaN    5.0       Manual  2015   test
# 7248           First  103.60    NaN    5.0       Manual  2011   test
# 7249           First  103.60    NaN    5.0    Automatic  2015   test
# 7250           First   63.10    NaN    5.0       Manual  2012   test
# 7251           Third  103.60    NaN    5.0    Automatic  2013   test
# 7252           First  170.00    NaN    5.0    Automatic  2014   test
#
# [7253 rows x 14 columns]

# %%
Models = []
for i in raw_data['Name'].values:
    tmp_list = i.split(" ")
    print(tmp_list)
    for j in tmp_list:
     Models.append(j)
    #break
# Out:
# ['Maruti', 'Wagon', 'R', 'LXI', 'CNG']
# ['Hyundai', 'Creta', '1.6', 'CRDi', 'SX', 'Option']
# ['Honda', 'Jazz', 'V']
# ['Maruti', 'Ertiga', 'VDI']
# ['Audi', 'A4', 'New', '2.0', 'TDI', 'Multitronic']
# ['Hyundai', 'EON', 'LPG', 'Era', 'Plus', 'Option']
# ['Nissan', 'Micra', 'Diesel', 'XV']
# ['Toyota', 'Innova', 'Crysta', '2.8', 'GX', 'AT', '8S']
# ['Volkswagen', 'Vento', 'Diesel', 'Comfortline']
# ['Tata', 'Indica', 'Vista', 'Quadrajet', 'LS']
# ['Maruti', 'Ciaz', 'Zeta']
# ['Honda', 'City', '1.5', 'V', 'AT', 'Sunroof']
# ['Maruti', 'Swift', 'VDI', 'BSIV']
# ['Land', 'Rover', 'Range', 'Rover', '2.2L', 'Pure']
# ['Land', 'Rover', 'Freelander', '2', 'TD4', 'SE']
# ['Mitsubishi', 'Pajero', 'Sport', '4X4']
# ['Honda', 'Amaze', 'S', 'i-Dtech']
# ['Maruti', 'Swift', 'DDiS', 'VDI']
# ['Renault', 'Duster', '85PS', 'Diesel', 'RxL', 'Plus']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220', 'CDI', 'BE', 'Avantgare']
# ['BMW', '3', 'Series', '320d']
# ['Maruti', 'S', 'Cross', 'DDiS', '200', 'Alpha']
# ['Audi', 'A6', '2011-2015', '35', 'TFSI', 'Technology']
# ['Hyundai', 'i20', '1.2', 'Magna']
# ['Volkswagen', 'Vento', 'Petrol', 'Highline', 'AT']
# ['Honda', 'City', 'Corporate', 'Edition']
# ['Nissan', 'Micra', 'Diesel', 'XV']
# ['Maruti', 'Alto', 'K10', '2010-2014', 'VXI']
# ['Honda', 'WRV', 'i-VTEC', 'VX']
# ['Toyota', 'Innova', '2.5', 'V', 'Diesel', '7-seater']
# ['Renault', 'Duster', '110PS', 'Diesel', 'RxZ', 'Pack']
# ['Toyota', 'Corolla', 'Altis', 'G']
# ['Mahindra', 'Ssangyong', 'Rexton', 'RX7']
# ['Audi', 'A6', '2.7', 'TDI']
# ['Volkswagen', 'Vento', '1.6', 'Highline']
# ['Maruti', 'Wagon', 'R', 'LXI', 'BSIII']
# ['Maruti', 'Vitara', 'Brezza', 'ZDi', 'Plus']
# ['Mahindra', 'KUV', '100', 'mFALCON', 'G80', 'K6', '5str', 'AW']
# ['Mercedes-Benz', 'M-Class', 'ML', '350', 'CDI']
# ['Volkswagen', 'Polo', 'Diesel', 'Trendline', '1.2L']
# ['Maruti', 'Alto', 'LXi']
# ['Tata', 'Nano', 'LX', 'SE']
# ['Mahindra', 'KUV', '100', 'mFALCON', 'D75', 'K8', 'Dual', 'Tone']
# ['Hyundai', 'i20', 'Magna', 'Optional', '1.2']
# ['Hyundai', 'Elantra', '2.0', 'SX', 'Option', 'AT']
# ['Toyota', 'Corolla', 'Altis', 'G', 'AT']
# ['Hyundai', 'Elantra', 'CRDi']
# ['Toyota', 'Innova', 'Crysta', '2.7', 'GX', 'MT']
# ['Hyundai', 'Xcent', '1.1', 'CRDi', 'S']
# ['Mahindra', 'Thar', 'CRDe', 'AC']
# ['Audi', 'A4', '2.0', 'TDI', '177', 'Bhp', 'Premium', 'Plus']
# ['Maruti', 'Swift', 'LDI']
# ['Maruti', 'Swift', 'Ldi', 'BSIV']
# ['Maruti', 'Swift', 'VDI']
# ['Hyundai', 'Grand', 'i10', 'Sportz']
# ['Volkswagen', 'Vento', '2013-2015', '1.6', 'Comfortline']
# ['Renault', 'KWID', 'RXT']
# ['Hyundai', 'i10', 'Asta']
# ['Nissan', 'X-Trail', 'SLX', 'AT']
# ['Maruti', 'Zen', 'Estilo', 'VXI', 'BSIII']
# ['Toyota', 'Innova', 'Crysta', '2.4', 'GX', 'MT', '8S']
# ['Ford', 'Figo', 'Diesel', 'Titanium']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '200', 'CGI', 'Avantgarde']
# ['Mercedes-Benz', 'New', 'C-Class', '200', 'CDI', 'Classic']
# ['Tata', 'Indica', 'V2', 'eLS']
# ['Audi', 'A4', '2.0', 'TDI', 'Multitronic']
# ['Honda', 'City', 'ZX', 'CVT']
# ['Mercedes-Benz', 'C-Class', 'Progressive', 'C', '220d']
# ['Maruti', 'Ertiga', 'SHVS', 'VDI']
# ['Hyundai', 'Creta', '1.4', 'E', 'Plus', 'Diesel']
# ['Porsche', 'Cayenne', '2009-2014', 'Turbo']
# ['Mahindra', 'XUV500', 'W8', '4WD']
# ['Hyundai', 'i10', 'Sportz', '1.2', 'AT']
# ['Nissan', 'Terrano', 'XV', 'D', 'Pre']
# ['Honda', 'Brio', 'VX', 'AT']
# ['Audi', 'A6', '2.0', 'TDI', 'Design', 'Edition']
# ['Ford', 'Fiesta', '1.4', 'SXi', 'TDCi']
# ['Toyota', 'Innova', '2.0', 'G1']
# ['Toyota', 'Innova', '2.5', 'VX', '7', 'STR', 'BSIV']
# ['Hyundai', 'Santro', 'Xing', 'XL']
# ['Maruti', 'Swift', 'VDI']
# ['Tata', 'Zest', 'Revotron', '1.2T', 'XE']
# ['Honda', 'Amaze', 'SX', 'i-VTEC']
# ['Ford', 'Figo', 'Diesel', 'ZXI']
# ['Maruti', 'Ritz', 'VDi']
# ['Honda', 'City', 'i', 'VTEC', 'E']
# ['BMW', '5', 'Series', '2003-2012', '525d']
# ['Hyundai', 'i10', 'Sportz', '1.2']
# ['Hyundai', 'Grand', 'i10', 'Sportz']
# ['Hyundai', 'Santro', 'Xing', 'XO']
# ['Honda', 'Amaze', 'SX', 'i-VTEC']
# ['Toyota', 'Fortuner', '4x2', 'Manual']
# ['Audi', 'A6', '2011-2015', '35', 'TDI', 'Premium']
# ['Ford', 'Ecosport', '1.5', 'DV5', 'MT', 'Titanium', 'Optional']
# ['Mahindra', 'XUV500', 'W8', '2WD']
# ['Honda', 'Amaze', 'SX', 'i-DTEC']
# ['Volkswagen', 'Polo', 'Diesel', 'Highline', '1.2L']
# ['Hyundai', 'Verna', 'Transform', 'SX', 'VGT', 'CRDi']
# ['Maruti', 'Wagon', 'R', 'VXI', 'BS', 'IV']
# ['Volkswagen', 'Polo', 'Petrol', 'Highline', '1.6L']
# ['Hyundai', 'i20', '1.4', 'CRDi', 'Sportz']
# ['Hyundai', 'i20', 'Asta', '1.2']
# ['Datsun', 'GO', 'Plus', 'T', 'Petrol']
# ['Audi', 'A4', '3.0', 'TDI', 'Quattro', 'Premium']
# ['Hyundai', 'i20', '2015-2017', 'Asta']
# ['Maruti', 'Omni', '5', 'Str', 'STD']
# ['Toyota', 'Etios', 'Liva', '1.2', 'G']
# ['Jaguar', 'XF', '3.0', 'Litre', 'S', 'Premium', 'Luxury']
# ['Mahindra', 'XUV500', 'W8', '2WD']
# ['Hyundai', 'Verna', '1.6', 'SX', 'CRDI', '(O)', 'AT']
# ['Toyota', 'Innova', 'Crysta', '2.8', 'ZX', 'AT']
# ['Maruti', 'Eeco', '5', 'Seater', 'AC']
# ['Tata', 'Nano', 'Twist', 'XT']
# ['BMW', '3', 'Series', '320d', 'Luxury', 'Line']
# ['Honda', 'Civic', '2006-2010', '1.8', 'V', 'MT']
# ['Toyota', 'Innova', '2.5', 'VX', '(Diesel)', '7', 'Seater']
# ['Volvo', 'V40', 'Cross', 'Country', 'D3']
# ['Nissan', 'Micra', 'XV', 'CVT']
# ['BMW', '5', 'Series', '2010-2013', '525i']
# ['Maruti', 'Vitara', 'Brezza', 'VDi']
# ['Hyundai', 'Santro', 'Xing', 'XL', 'eRLX', 'Euro', 'III']
# ['Mercedes-Benz', 'B', 'Class', 'B200', 'CDI']
# ['Hyundai', 'Verna', 'CRDi', '1.6', 'SX', 'Option']
# ['Maruti', 'Wagon', 'R', 'LXI', 'BS', 'IV']
# ['Tata', 'Nano', 'XTA']
# ['Mahindra', 'Scorpio', 'VLX']
# ['Mercedes-Benz', 'New', 'C-Class', '200', 'K', 'AT']
# ['Maruti', 'Wagon', 'R', 'LXI', 'CNG']
# ['Honda', 'CR-V', '2.4', 'MT']
# ['Volkswagen', 'Vento', '1.5', 'TDI', 'Comfortline', 'AT']
# ['Maruti', 'Ciaz', 'VXi', 'Plus']
# ['Mahindra', 'XUV500', 'AT', 'W10', 'FWD']
# ['Maruti', 'Ritz', 'VXI', 'ABS']
# ['Maruti', 'Alto', 'K10', 'VXI']
# ['Mercedes-Benz', 'SLC', '43', 'AMG']
# ['Hyundai', 'Verna', 'VTVT', '1.6', 'AT', 'SX', 'Plus']
# ['Maruti', 'Alto', 'LXi', 'BSIII']
# ['BMW', '1', 'Series', '118d', 'Base']
# ['Honda', 'Jazz', '1.2', 'V', 'CVT', 'i', 'VTEC']
# ['Honda', 'Civic', '2006-2010', '1.8', 'V', 'MT']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220', 'CDI', 'Avantgarde']
# ['Honda', 'Amaze', 'SX', 'i-DTEC']
# ['Maruti', 'Swift', 'VVT', 'VXI']
# ['Hyundai', 'Santro', 'Xing', 'XO', 'eRLX', 'Euro', 'II']
# ['Toyota', 'Fortuner', '3.0', 'Diesel']
# ['Chevrolet', 'Beat', 'LT', 'Option']
# ['Skoda', 'Rapid', '1.5', 'TDI', 'Elegance']
# ['Maruti', 'Ciaz', '1.4', 'Alpha']
# ['Audi', 'RS5', 'Coupe']
# ['BMW', '3', 'Series', 'Luxury', 'Line']
# ['Audi', 'A4', '2.0', 'TDI', '177', 'Bhp', 'Premium', 'Plus']
# ['Maruti', 'Swift', 'VDI']
# ['Mercedes-Benz', 'S', 'Class', '2005', '2013', 'S', '500']
# ['Skoda', 'Rapid', '1.5', 'TDI', 'AT', 'Elegance', 'Plus', 'Black', 'Package']
# ['Skoda', 'Superb', 'Elegance', '2.0', 'TDI', 'CR', 'AT']
# ['Hyundai', 'EON', 'Magna', 'Plus']
# ['Volkswagen', 'Polo', 'Diesel', 'Trendline', '1.2L']
# ['Datsun', 'GO', 'NXT']
# ['Honda', 'Brio', 'S', 'MT']
# ['Mercedes-Benz', 'B', 'Class', 'B180']
# ['Honda', 'City', 'i', 'DTEC', 'V']
# ['Toyota', 'Innova', '2.5', 'G', '(Diesel)', '7', 'Seater']
# ['Maruti', 'Swift', 'VXI', 'Optional']
# ['Mahindra', 'XUV500', 'W8', '2WD']
# ['Ford', 'Ecosport', '1.5', 'DV5', 'MT', 'Ambiente']
# ['Toyota', 'Fortuner', '4x2', 'Manual']
# ['Volkswagen', 'Vento', '1.5', 'Highline', 'Plus', 'AT', '16', 'Alloy']
# ['Ford', 'Figo', 'Diesel', 'Titanium']
# ['BMW', 'X5', 'xDrive', '30d']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220', 'CDI', 'Style']
# ['Honda', 'Brio', 'V', 'MT']
# ['Hyundai', 'i10', 'Magna', '1.2']
# ['Mercedes-Benz', 'GLC', '220']
# ['Hyundai', 'Grand', 'i10', '1.2', 'Kappa', 'Asta']
# ['Audi', 'A6', '2011-2015', '2.0', 'TDI', 'Premium', 'Plus']
# ['Volkswagen', 'Vento', 'Petrol', 'Highline', 'AT']
# ['Mini', 'Countryman', 'Cooper', 'D']
# ['Hyundai', 'i20', 'Asta', '1.4', 'CRDi']
# ['Audi', 'A6', '2011-2015', '2.0', 'TDI', 'Premium', 'Plus']
# ['Chevrolet', 'Beat', 'Diesel', 'LT']
# ['Skoda', 'Superb', 'Elegance', '1.8', 'TSI', 'AT']
# ['Ford', 'Fiesta', '1.4', 'TDCi', 'EXI', 'Limited', 'Edition']
# ['BMW', '5', 'Series', '520d', 'Luxury', 'Line']
# ['Chevrolet', 'Optra', 'Magnum', '1.6', 'LS', 'BS3']
# ['Volkswagen', 'Polo', 'Diesel', 'Highline', '1.2L']
# ['Renault', 'Lodgy', '110PS', 'RxZ', '8', 'Seater']
# ['Mercedes-Benz', 'E-Class', 'E250', 'CDI', 'Avantgrade']
# ['Maruti', 'Baleno', 'Alpha']
# ['Hyundai', 'Verna', '1.6', 'SX']
# ['Hyundai', 'i10', 'Magna', '1.1']
# ['Mahindra', 'Scorpio', '1.99', 'S10', '4WD']
# ['Land', 'Rover', 'Range', 'Rover', '2.2L', 'Dynamic']
# ['Ford', 'Figo', 'Diesel', 'ZXI']
# ['Maruti', 'Ertiga', 'ZDI']
# ['Honda', 'City', '1.5', 'GXI']
# ['Honda', 'Amaze', 'S', 'i-Dtech']
# ['Hyundai', 'i10', 'Magna']
# ['Honda', 'Amaze', 'S', 'i-Dtech']
# ['Skoda', 'Laura', 'Ambiente']
# ['Renault', 'Duster', '85PS', 'Diesel', 'RxL']
# ['Mahindra', 'NuvoSport', 'N6']
# ['Maruti', 'Vitara', 'Brezza', 'ZDi', 'Plus', 'Dual', 'Tone']
# ['Hyundai', 'i20', 'Asta', 'Option', '1.2']
# ['Skoda', 'Fabia', '1.4', 'MPI', 'Ambiente']
# ['Tata', 'Indigo', 'eCS', 'GLX']
# ['Audi', 'Q3', '2012-2015', '35', 'TDI', 'Quattro', 'Premium', 'Plus']
# ['Skoda', 'Octavia', 'Elegance', '1.8', 'TSI', 'AT']
# ['Toyota', 'Etios', 'Liva', 'GD', 'SP']
# ['Maruti', 'Swift', '1.3', 'VXi']
# ['Mercedes-Benz', 'B', 'Class', 'B180']
# ['Honda', 'Amaze', 'S', 'Diesel']
# ['Hyundai', 'Verna', '1.6', 'SX']
# ['Renault', 'Duster', '85PS', 'Diesel', 'RxL', 'Optional']
# ['Hyundai', 'Creta', '1.6', 'VTVT', 'S']
# ['Maruti', 'Wagon', 'R', 'AMT', 'VXI']
# ['Mercedes-Benz', 'New', 'C-Class', 'C250', 'Avantgarde']
# ['Audi', 'A8', 'L', '3.0', 'TDI', 'quattro']
# ['Hyundai', 'i10', 'Magna', '1.1']
# ['Skoda', 'Rapid', '1.6', 'MPI', 'AT', 'Style', 'Black', 'Package']
# ['Skoda', 'Superb', 'Style', '1.8', 'TSI', 'AT']
# ['Hyundai', 'i20', 'Active', '1.2', 'SX']
# ['Honda', 'Amaze', 'VX', 'i-DTEC']
# ['Maruti', 'Wagon', 'R', 'LXI']
# ['Mahindra', 'Verito', '1.5', 'D4', 'BSIV']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220d', 'Avantgarde', 'Edition', 'C']
# ['Maruti', 'Wagon', 'R', 'VXI']
# ['Nissan', 'Terrano', 'XV', 'Premium', '110', 'PS', 'Anniversary', 'Edition']
# ['Maruti', 'Swift', 'VDI', 'BSIV']
# ['Mini', 'Cooper', 'Convertible', 'S']
# ['Ford', 'Figo', 'Diesel']
# ['Tata', 'Indica', 'V2', 'DLS', 'BSII']
# ['Chevrolet', 'Beat', 'LT']
# ['Volkswagen', 'Polo', 'Diesel', 'Comfortline', '1.2L']
# ['Maruti', 'Swift', 'ZDi']
# ['Ford', 'Figo', 'Diesel', 'EXI']
# ['Toyota', 'Innova', 'Crysta', '2.8', 'GX', 'AT']
# ['Hyundai', 'Santa', 'Fe', '4x4', 'AT']
# ['Honda', 'City', 'i-VTEC', 'V']
# ['Hyundai', 'i20', '1.2', 'Magna', 'Executive']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220d', 'Avantgarde', 'Edition', 'C']
# ['Chevrolet', 'Beat', 'Diesel', 'LT']
# ['Hyundai', 'i20', 'Sportz', '1.4', 'CRDi']
# ['Toyota', 'Innova', '2.5', 'Z', 'Diesel', '7', 'Seater']
# ['Maruti', 'Ertiga', 'VDI']
# ['Toyota', 'Innova', '2.5', 'V', 'Diesel', '7-seater']
# ['Hyundai', 'Santro', 'Xing', 'XO', 'eRLX', 'Euro', 'II']
# ['Honda', 'City', 'i', 'VTEC', 'V']
# ['BMW', 'X1', 'sDrive20d']
# ['Hyundai', 'Grand', 'i10', 'CRDi', 'Era']
# ['Maruti', 'Ciaz', '1.3', 'Alpha']
# ['Skoda', 'Rapid', 'Leisure', '1.6', 'TDI', 'MT']
# ['Hyundai', 'Accent', 'CRDi']
# ['Volkswagen', 'Polo', 'GT', '1.5', 'TDI']
# ['Honda', 'Jazz', '1.2', 'VX', 'i', 'VTEC']
# ['Hyundai', 'i10', 'Era']
# ['Hyundai', 'Tucson', '2.0', 'e-VGT', '2WD', 'AT', 'GLS']
# ['Toyota', 'Innova', 'Crysta', '2.4', 'ZX', 'MT']
# ['Maruti', 'Omni', 'MPI', 'CARGO', 'BSIII', 'W/', 'IMMOBILISER']
# ['Maruti', 'Swift', 'VXI', 'BSIV']
# ['Hyundai', 'Grand', 'i10', 'Magna']
# ['Maruti', 'Swift', 'VDI']
# ['Hyundai', 'Verna', 'CRDi', '1.6', 'SX']
# ['Hyundai', 'Santro', 'Xing', 'XL']
# ['Hyundai', 'i20', '1.2', 'Sportz']
# ['Mercedes-Benz', 'GLE', '350d']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220', 'CDI', 'CLASSIC']
# ['Maruti', 'Ritz', 'ZDi']
# ['Hyundai', 'Creta', '1.6', 'CRDi', 'SX']
# ['Maruti', 'A-Star', 'Vxi']
# ['Renault', 'Duster', '110PS', 'Diesel', 'RXZ', 'Option']
# ['Fiat', 'Grande', 'Punto', '1.3', 'Emotion', 'Pack', '(Diesel)']
# ['BMW', 'X3', 'xDrive30d', 'M', 'Sport']
# ['Hyundai', 'i10', 'Sportz']
# ['Toyota', 'Innova', '2.5', 'G4', 'Diesel', '7-seater']
# ['Maruti', 'Zen', 'VXI', 'BSII']
# ['Maruti', 'Swift', 'VDI']
# ['Mahindra', 'Scorpio', 'VLX', '2.2', 'mHawk', 'Airbag', 'BSIV']
# ['Tata', 'Zest', 'Quadrajet', '1.3', '75PS', 'XE']
# ['Ford', 'EcoSport', '1.0', 'Ecoboost', 'Titanium', 'Plus']
# ['Maruti', 'Swift', 'Dzire', 'ZDI']
# ['Maruti', 'Alto', '800', 'LXI']
# ['Honda', 'City', '1.5', 'S', 'MT']
# ['Audi', 'Q7', '3.0', 'TDI', 'Quattro', 'Technology']
# ['Skoda', 'Laura', '1.9', 'TDI', 'AT', 'Ambiente']
# ['Hyundai', 'Verna', '1.6', 'SX', 'VTVT', '(O)']
# ['Honda', 'City', '1.5', 'V', 'AT']
# ['Hyundai', 'i20', 'Magna', 'Optional', '1.4', 'CRDi']
# ['Hyundai', 'i20', 'Sportz', 'AT', '1.4']
# ['Volkswagen', 'Vento', 'Diesel', 'Highline']
# ['Honda', 'City', 'i', 'VTEC', 'VX']
# ['Tata', 'Zest', 'Quadrajet', '1.3', '75PS', 'XE']
# ['BMW', '5', 'Series', '2003-2012', '520d']
# ['Maruti', 'Wagon', 'R', 'LXI', 'Minor']
# ['Honda', 'Jazz', 'VX']
# ['Volkswagen', 'Jetta', '2007-2011', '2.0', 'TDI', 'Comfortline']
# ['Hyundai', 'i10', 'Magna', '1.2']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220', 'CDI', 'Avantgarde']
# ['Hyundai', 'i10', 'Magna', '1.2', 'iTech', 'SE']
# ['Toyota', 'Innova', 'Crysta', '2.4', 'ZX', 'MT']
# ['Audi', 'A6', '2011-2015', '2.0', 'TDI', 'Technology']
# ['Toyota', 'Innova', '2.5', 'VX', '(Diesel)', '7', 'Seater']
# ['Volkswagen', 'Polo', 'Petrol', 'Trendline', '1.2L']
# ['Maruti', 'Alto', 'K10', 'LXI']
# ['Honda', 'City', 'i-VTEC', 'CVT', 'ZX']
# ['Tata', 'Indigo', 'LX']
# ['Audi', 'A6', '2011-2015', '2.0', 'TDI', 'Premium', 'Plus']
# ['Mercedes-Benz', 'GLA', 'Class', '200', 'CDI', 'SPORT']
# ['Hyundai', 'Santro', 'Xing', 'XL']
# ['Maruti', 'Swift', 'VDI', 'BSIV']
# ['Maruti', 'Celerio', 'VXI', 'AT']
# ['Mercedes-Benz', 'GLE', '250d']
# ['Land', 'Rover', 'Range', 'Rover', 'HSE', 'Dynamic']
# ['Volkswagen', 'Vento', 'Diesel', 'Trendline']
# ['Maruti', 'Omni', '8', 'Seater', 'BSIV']
# ['Honda', 'Brio', '1.2', 'VX', 'MT']
# ['Tata', 'Sumo', 'Delux']
# ['Tata', 'Indica', 'Vista', 'Aura', '1.3', 'Quadrajet']
# ['Maruti', 'Wagon', 'R', 'LXI', 'BS', 'IV']
# ['Mahindra', 'XUV500', 'W8', '4WD']
# ['Tata', 'Indigo', 'LS', 'Dicor']
# ['Maruti', 'Ertiga', 'Paseo', 'VXI']
# ['Honda', 'Accord', '2.4', 'A/T']
# ['Maruti', 'Swift', 'Dzire', 'VDi']
# ['Ford', 'Fiesta', 'EXi', '1.4', 'TDCi', 'Ltd']
# ['Honda', 'City', 'ZX', 'GXi']
# ['Audi', 'A6', '2011-2015', '2.0', 'TDI', 'Premium', 'Plus']
# ['BMW', '6', 'Series', '640d', 'Gran', 'Coupe']
# ['Audi', 'Q7', '45', 'TDI', 'Quattro', 'Technology']
# ['Maruti', 'Zen', 'Estilo', 'LXI', 'Green', '(CNG)']
# ['Hyundai', 'i20', '1.4', 'CRDi', 'Asta']
# ['Hyundai', 'i10', 'Sportz', 'AT']
# ['Honda', 'Jazz', '1.2', 'V', 'CVT', 'i', 'VTEC']
# ['Maruti', 'Swift', 'VDI', 'BSIV']
# ['Hyundai', 'i20', 'Asta', '1.2']
# ['Volkswagen', 'Polo', 'Petrol', 'Comfortline', '1.2L']
# ['Maruti', 'Alto', 'LXi']
# ['Toyota', 'Corolla', 'H4']
# ['Maruti', 'Alto', 'LXi']
# ['Tata', 'Manza', 'ELAN', 'Quadrajet', 'BS', 'IV']
# ['Maruti', 'Alto', 'LXi']
# ['Skoda', 'Octavia', 'Ambition', 'Plus', '2.0', 'TDI', 'AT']
# ['Toyota', 'Corolla', 'H4']
# ['Hyundai', 'i20', 'Asta', 'Option', '1.2']
# ['Maruti', 'Vitara', 'Brezza', 'LDi']
# ['Honda', 'City', '1.5', 'V', 'MT']
# ['Tata', 'Indica', 'Vista', 'Aqua', '1.3', 'Quadrajet']
# ['Honda', 'Amaze', 'S', 'i-Dtech']
# ['Hyundai', 'EON', 'D', 'Lite', 'Plus']
# ['BMW', '3', 'Series', 'Luxury', 'Line']
# ['Hyundai', 'Verna', '1.6', 'SX']
# ['Tata', 'Manza', 'Club', 'Class', 'Quadrajet90', 'LS']
# ['Skoda', 'Octavia', 'RS']
# ['Maruti', 'Alto', 'K10', 'VXI']
# ['Ford', 'Ecosport', '1.5', 'DV5', 'MT', 'Titanium', 'Optional']
# ['Chevrolet', 'Spark', '1.0', 'LS']
# ['Jaguar', 'XF', '2.0', 'Diesel', 'Portfolio']
# ['Honda', 'CR-V', 'RVi', 'MT']
# ['Skoda', 'Superb', 'L&K', '1.8', 'TSI', 'AT']
# ['Hyundai', 'i10', 'Magna', '1.2']
# ['Maruti', 'Swift', 'LDI']
# ['Maruti', 'Swift', 'Dzire', 'VXi', 'AT']
# ['Nissan', 'Micra', 'Diesel', 'XV']
# ['Maruti', 'Swift', 'Dzire', 'Tour', 'LDI']
# ['Ford', 'Fiesta', 'Classic', '1.4', 'Duratorq', 'CLXI']
# ['Maruti', 'Zen', 'LX']
# ['Mini', 'Clubman', 'Cooper', 'S']
# ['Toyota', 'Etios', 'GD']
# ['Maruti', 'Alto', '800', '2016-2019', 'LXI']
# ['Maruti', 'Alto', 'VXi']
# ['BMW', 'X5', '3.0d']
# ['Nissan', 'Teana', 'XV']
# ['Hyundai', 'Grand', 'i10', 'AT', 'Asta']
# ['Maruti', 'Vitara', 'Brezza', 'ZDi', 'Plus']
# ['Audi', 'Q7', '3.0', 'TDI', 'Quattro', 'Premium', 'Plus']
# ['Mercedes-Benz', 'GLA', 'Class', '200', 'CDI']
# ['Maruti', '800', 'AC']
# ['Renault', 'Duster', '85PS', 'Diesel', 'RxL']
# ['Toyota', 'Corolla', 'Altis', 'D-4D', 'GL']
# ['Mercedes-Benz', 'New', 'C-Class', '220']
# ['Maruti', 'Ritz', 'VDi']
# ['Honda', 'BRV', 'i-VTEC', 'V', 'CVT']
# ['Hyundai', 'Xcent', '1.1', 'CRDi', 'Base']
# ['Mercedes-Benz', 'E-Class', '2009-2013', 'E250', 'CDI', 'Avantgarde']
# ['Mercedes-Benz', 'B', 'Class', 'B180']
# ['Mercedes-Benz', 'E-Class', '2015-2017', 'E250', 'Edition', 'E']
# ['Honda', 'City', 'i', 'VTEC', 'VX', 'Option']
# ['Hyundai', 'Santro', 'Xing', 'XL', 'eRLX', 'Euro', 'III']
# ['Honda', 'City', '1.5', 'S', 'MT']
# ['Hyundai', 'Verna', 'Transform', 'VTVT']
# ['Jaguar', 'XE', 'Portfolio']
# ['Honda', 'Amaze', 'S', 'i-Vtech']
# ['Mini', 'Cooper', 'Convertible', '1.6']
# ['Mercedes-Benz', 'S', 'Class', '2005', '2013', 'S', '350', 'CDI']
# ['Hyundai', 'EON', 'Magna', 'Plus']
# ['Maruti', 'Wagon', 'R', 'VXI', 'BS', 'IV']
# ['Maruti', 'Ritz', 'LDi']
# ['BMW', '3', 'Series', '320d', 'Sedan']
# ['Tata', 'Xenon', 'XT', 'EX', '4X2']
# ['Audi', 'A3', '35', 'TDI', 'Attraction']
# ['Land', 'Rover', 'Range', 'Rover', '2.2L', 'Dynamic']
# ['Mercedes-Benz', 'GL-Class', '2007', '2012', '350', 'CDI', 'Luxury']
# ['Mitsubishi', 'Pajero', 'Sport', '4X2', 'AT', 'DualTone', 'BlackTop']
# ['Maruti', 'Alto', 'LX']
# ['Maruti', 'Wagon', 'R', 'LXI', 'BSIII']
# ['Land', 'Rover', 'Range', 'Rover', '2.2L', 'Prestige']
# ['Hyundai', 'Verna', '1.6', 'SX', 'VTVT']
# ['BMW', '5', 'Series', '525d', 'Sedan']
# ['Jaguar', 'XF', 'Diesel']
# ['Skoda', 'Superb', 'Elegance', '1.8', 'TSI', 'AT']
# ['Audi', 'Q3', '35', 'TDI', 'Quattro', 'Premium']
# ['Land', 'Rover', 'Range', 'Rover', '2.2L', 'Pure']
# ['Mercedes-Benz', 'New', 'C-Class', '220', 'CDI', 'AT']
# ['Mahindra', 'Scorpio', 'S10', '4WD']
# ['BMW', '3', 'Series', 'Luxury', 'Line']
# ['Honda', 'BR-V', 'i-VTEC', 'S', 'MT']
# ['Volvo', 'S80', '2006-2013', 'D5']
# ['Hyundai', 'Accent', 'GLE']
# ['Hyundai', 'i20', 'Active', 'SX', 'Petrol']
# ['Mercedes-Benz', 'GLC', '43', 'AMG', 'Coupe']
# ['Hyundai', 'EON', 'Magna', 'Plus']
# ['Hyundai', 'Grand', 'i10', 'SportZ', 'Edition']
# ['Honda', 'City', '1.5', 'EXI', 'S']
# ['Volkswagen', 'Polo', 'Petrol', 'Trendline', '1.2L']
# ['Audi', 'A6', '35', 'TFSI', 'Matrix']
# ['Volkswagen', 'Jetta', '2007-2011', '1.9', 'L', 'TDI']
# ['Hyundai', 'Creta', '1.6', 'SX', 'Plus', 'Dual', 'Tone', 'Petrol']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '200', 'CGI', 'Avantgarde']
# ['Mini', 'Cooper', 'Convertible', 'S']
# ['Hyundai', 'Santro', 'Xing', 'XO', 'eRLX', 'Euro', 'II']
# ['Toyota', 'Etios', 'VD']
# ['Honda', 'Brio', 'S', 'MT']
# ['Maruti', 'Baleno', 'Alpha', 'Automatic']
# ['Skoda', 'Laura', 'Ambiente', '2.0', 'TDI', 'CR', 'AT']
# ['Hyundai', 'EON', 'Era', 'Plus']
# ['Renault', 'Captur', '1.5', 'Diesel', 'RXL']
# ['BMW', '5', 'Series', '2003-2012', 'GT', '530d', 'LE']
# ['Maruti', 'Alto', '800', 'LXI']
# ['Volvo', 'V40', 'D3']
# ['Maruti', 'Wagon', 'R', 'LXI', 'BSII']
# ['Honda', 'City', 'ZX', 'GXi']
# ['Maruti', 'Eeco', '5', 'STR', 'With', 'AC', 'Plus', 'HTR', 'CNG']
# ['Chevrolet', 'Enjoy', '1.4', 'LS', '8']
# ['Mahindra', 'Bolero', 'ZLX']
# ['Hyundai', 'Santro', 'GLS', 'I', '-', 'Euro', 'I']
# ['Hyundai', 'EON', 'D', 'Lite']
# ['Hyundai', 'Creta', '1.6', 'SX', 'Plus', 'Petrol', 'Automatic']
# ['Volkswagen', 'Vento', '1.6', 'Comfortline']
# ['Honda', 'Civic', '2006-2010', '1.8', 'S', 'AT']
# ['Tata', 'Indica', 'Vista', 'Quadrajet', 'LS']
# ['Mahindra', 'XUV500', 'W8', '2WD']
# ['Hyundai', 'i20', '1.2', 'Asta', 'Option']
# ['Audi', 'Q5', '30', 'TDI', 'quattro', 'Premium', 'Plus']
# ['Maruti', 'Ritz', 'VXi']
# ['Mitsubishi', 'Cedia', 'Sports']
# ['Toyota', 'Innova', '2.5', 'V', 'Diesel', '7-seater']
# ['Maruti', 'Celerio', 'LDi']
# ['Maruti', 'S-Cross', 'Delta', 'DDiS', '200', 'SH']
# ['Audi', 'Q3', '35', 'TDI', 'Quattro', 'Premium', 'Plus']
# ['BMW', '3', 'Series', 'Luxury', 'Line']
# ['Audi', 'Q7', '4.2', 'TDI', 'Quattro', 'Technology']
# ['Hyundai', 'i20', '2015-2017', 'Asta', '1.2']
# ['Renault', 'Duster', '110PS', 'Diesel', 'RxL']
# ['Hyundai', 'Xcent', '1.1', 'CRDi', 'S', 'Celebration', 'Edition']
# ['Ford', 'Ecosport', '1.5', 'DV5', 'MT', 'Titanium']
# ['Volkswagen', 'Polo', 'Petrol', 'Trendline', '1.2L']
# ['Hyundai', 'Grand', 'i10', 'CRDi', 'Magna']
# ['Tata', 'Manza', 'Aqua', 'Quadrajet', 'BS', 'IV']
# ['Honda', 'City', '1.5', 'V', 'MT']
# ['Hyundai', 'Santro', 'Xing', 'GLS']
# ['Toyota', 'Innova', '2.5', 'VX', '(Diesel)', '7', 'Seater']
# ['Maruti', 'Ciaz', '1.3', 'S']
# ['Toyota', 'Fortuner', '4x4', 'MT', 'TRD', 'Sportivo']
# ['Ford', 'Fiesta', '1.6', 'SXI', 'ABS', 'Duratec']
# ['Mercedes-Benz', 'E-Class', 'E', '220', 'd']
# ['Mercedes-Benz', 'New', 'C-Class', '220', 'CDI', 'MT']
# ['Skoda', 'Yeti', 'Ambition', '4X2']
# ['Hyundai', 'Grand', 'i10', 'Sportz']
# ['Ford', 'Figo', '2015-2019', '1.2P', 'Titanium', 'MT']
# ['Skoda', 'Octavia', 'Ambition', '1.4', 'TSI', 'MT']
# ['Renault', 'Duster', '85PS', 'Diesel', 'RxL', 'Option']
# ['Land', 'Rover', 'Range', 'Rover', 'Evoque', '2.0', 'TD4', 'Pure']
# ['Ford', 'Figo', 'Diesel', 'EXI']
# ['Ford', 'Endeavour', 'Hurricane', 'Limited', 'Edition']
# ['Toyota', 'Fortuner', '4x4', 'MT']
# ['Volkswagen', 'Polo', 'Diesel', 'Comfortline', '1.2L']
# ['Maruti', 'Ritz', 'VDi']
# ['Nissan', 'Micra', 'Diesel', 'XV', 'Premium']
# ['Hyundai', 'Verna', '1.6', 'SX']
# ['BMW', '5', 'Series', '2003-2012', '523i']
# ['Mercedes-Benz', 'GLS', '350d', '4MATIC']
# ['Honda', 'CR-V', '2.4L', '4WD', 'AT']
# ['Hyundai', 'Creta', '1.6', 'CRDi', 'AT', 'SX', 'Plus']
# ['Hyundai', 'i10', 'Era']
# ['Mercedes-Benz', 'A', 'Class', 'A200', 'CDI', 'Sport']
# ['Maruti', 'Ertiga', 'VXI']
# ['Skoda', 'Octavia', 'Classic', '1.9', 'TDI', 'MT']
# ['Honda', 'Amaze', 'VX', 'i-Vtech']
# ['Maruti', 'Zen', 'LXi', 'BSII']
# ['Maruti', 'SX4', 'ZXI', 'MT', 'BSIV']
# ['Honda', 'Brio', 'VX', 'AT']
# ['Maruti', 'Wagon', 'R', 'VXI']
# ['Toyota', 'Camry', 'A/T']
# ['Chevrolet', 'Beat', 'LS']
# ['Toyota', 'Fortuner', '4x4', 'AT']
# ['Ford', 'Ecosport', '1.5', 'DV5', 'MT', 'Titanium', 'Optional']
# ['Maruti', 'Swift', 'Vdi', 'BSIII']
# ['Mercedes-Benz', 'S', 'Class', '2005', '2013', 'S', '350', 'CDI']
# ['Honda', 'Mobilio', 'S', 'i', 'VTEC']
# ['Hyundai', 'Grand', 'i10', 'Sportz']
# ['Mahindra', 'XUV500', 'AT', 'W8', 'FWD']
# ['Skoda', 'Fabia', '1.6', 'MPI', 'Elegance']
# ['Hyundai', 'Santro', 'Xing', 'GLS']
# ['Hyundai', 'Creta', '1.6', 'SX', 'Plus', 'Dual', 'Tone', 'Petrol']
# ['Mahindra', 'Scorpio', '1.99', 'S8']
# ['Skoda', 'Rapid', '1.6', 'TDI', 'Ambition']
# ['Renault', 'Duster', '110PS', 'Diesel', 'RxZ']
# ['BMW', 'X5', 'xDrive', '30d']
# ['Toyota', 'Etios', 'G']
# ['Maruti', 'Wagon', 'R', 'LXI']
# ['Hyundai', 'Creta', '1.6', 'SX']
# ['Maruti', 'Celerio', 'VXI']
# ['Land', 'Rover', 'Range', 'Rover', 'HSE', 'Dynamic']
# ['Chevrolet', 'Beat', 'LT']
# ['Tata', 'Nano', 'Twist', 'XT']
# ['Audi', 'A6', '2011-2015', '35', 'TDI', 'Technology']
# ['Mercedes-Benz', 'E-Class', '280', 'CDI']
# ['Maruti', 'Swift', 'VXI']
# ['Fiat', 'Linea', 'T', 'Jet']
# ['Maruti', 'Swift', 'VXI', 'Optional']
# ['Toyota', 'Fortuner', '3.0', 'Diesel']
# ['Maruti', 'Ertiga', 'ZXI']
# ['BMW', '3', 'Series', '320i', 'Sedan']
# ['Maruti', 'Ertiga', 'VXI']
# ['Honda', 'City', '1.5', 'V', 'AT']
# ['Hyundai', 'Santa', 'Fe', '4X4']
# ['Tata', 'Indigo', 'LS']
# ['Mercedes-Benz', 'E-Class', '2009-2013', 'E', '250', 'Elegance']
# ['Maruti', 'Swift', 'Dzire', 'LDi']
# ['Ford', 'Fiesta', 'Classic', '1.4', 'Duratorq', 'CLXI']
# ['Honda', 'City', 'i', 'VTEC', 'CVT', 'VX']
# ['Toyota', 'Fortuner', '4x2', 'Manual']
# ['Honda', 'Amaze', 'VX', 'O', 'i', 'VTEC']
# ['Hyundai', 'i20', 'Asta', '1.4', 'CRDi']
# ['Chevrolet', 'Enjoy', 'TCDi', 'LTZ', '7', 'Seater']
# ['Mercedes-Benz', 'New', 'C-Class', 'Progressive', 'C', '200']
# ['Maruti', 'SX4', 'ZXI', 'AT', 'Leather']
# ['Toyota', 'Innova', '2.5', 'VX', '(Diesel)', '7', 'Seater']
# ['BMW', '5', 'Series', '2003-2012', '520d']
# ['Renault', 'Duster', '110PS', 'Diesel', 'RxZ']
# ['BMW', 'X1', 'sDrive', '20d', 'xLine']
# ['Honda', 'City', 'ZX', 'GXi']
# ['Maruti', 'Ciaz', 'RS', 'ZDi', 'Plus', 'SHVS']
# ['Maruti', 'Swift', 'Dzire', 'VXi']
# ['Mahindra', 'XUV500', 'W6', '2WD']
# ['Honda', 'Civic', '2006-2010', '1.8', 'S', 'MT']
# ['Maruti', 'Ertiga', 'ZDI']
# ['Toyota', 'Etios', 'Liva', 'GD']
# ['Audi', 'TT', '2.0', 'TFSI']
# ['Skoda', 'Rapid', '1.5', 'TDI', 'Style']
# ['Volkswagen', 'Polo', '1.5', 'TDI', 'Highline']
# ['Skoda', 'Laura', '1.9', 'TDI', 'AT', 'Elegance']
# ['Mahindra', 'Renault', 'Logan', '1.5', 'DLE', 'Diesel']
# ['Toyota', 'Innova', 'Crysta', '2.8', 'GX', 'AT']
# ['BMW', '3', 'Series', '320d', 'Luxury', 'Line']
# ['Honda', 'Jazz', '1.5', 'S', 'i', 'DTEC']
# ['Honda', 'Amaze', 'VX', 'i-DTEC']
# ['Jaguar', 'XF', '2.2', 'Litre', 'Luxury']
# ['Maruti', 'Swift', 'Dzire', 'VDI']
# ['Jeep', 'Compass', '2.0', 'Limited']
# ['Toyota', 'Corolla', 'Altis', '1.8', 'Sport']
# ['Honda', 'City', '1.5', 'V', 'MT']
# ['Maruti', 'Swift', 'ZXI']
# ['Hyundai', 'Verna', '1.6', 'SX', 'CRDI', '(O)', 'AT']
# ['Mahindra', 'Bolero', 'ZLX']
# ['Maruti', 'Swift', 'VDI']
# ['Hyundai', 'Santro', 'Xing', 'XO']
# ['Audi', 'A6', '2011-2015', '2.0', 'TDI', 'Premium', 'Plus']
# ['Ford', 'Ikon', '1.3', 'LXi', 'NXt']
# ['Volkswagen', 'Polo', '1.5', 'TDI', 'Highline']
# ['Mahindra', 'Bolero', 'VLX', 'CRDe']
# ['Honda', 'City', 'i', 'DTEC', 'VX', 'Option']
# ['Chevrolet', 'Sail', 'Hatchback', '1.2', 'LS']
# ['Hyundai', 'i20', '1.2', 'Spotz']
# ['BMW', 'X1', 'sDrive', '20d', 'Sportline']
# ['BMW', 'X1', 'sDrive', '20d', 'Exclusive']
# ['Toyota', 'Fortuner', '4x2', 'AT']
# ['Audi', 'Q7', '4.2', 'TDI', 'Quattro', 'Technology']
# ['Maruti', 'Ertiga', 'VDI']
# ['Hyundai', 'i20', '1.2', 'Magna']
# ['Mercedes-Benz', 'S', 'Class', '2005', '2013', 'S', '350', 'L']
# ['Renault', 'Duster', '85PS', 'Diesel', 'RxL']
# ['Mahindra', 'Quanto', 'C2']
# ['Toyota', 'Fortuner', '4x2', 'AT']
# ['BMW', 'X5', '2014-2019', 'xDrive', '30d', 'Design', 'Pure', 'Experience', '7', 'Seater']
# ['Maruti', 'Swift', 'Dzire', 'VDi']
# ['Maruti', 'Swift', 'LDI', 'Optional']
# ['Audi', 'A6', '2011-2015', '35', 'TFSI', 'Technology']
# ['Mitsubishi', 'Pajero', '2.8', 'SFX', 'BSIV', 'Dual', 'Tone']
# ['Jaguar', 'XF', '2.2', 'Litre', 'Executive']
# ['Toyota', 'Innova', 'Crysta', '2.8', 'ZX', 'AT']
# ['Skoda', 'Octavia', 'Ambition', '2.0', 'TDI', 'AT']
# ['Toyota', 'Corolla', 'Altis', 'VL', 'AT']
# ['Maruti', 'Omni', '8', 'Seater', 'BSII']
# ['Mercedes-Benz', 'GLC', '220d', '4MATIC', 'Style']
# ['Volkswagen', 'Vento', '1.5', 'TDI', 'Highline', 'AT']
# ['Mahindra', 'XUV500', 'W10', '2WD']
# ['Nissan', 'Terrano', 'XL', '85', 'PS']
# ['Hyundai', 'Verna', '1.6', 'SX', 'CRDi', '(O)']
# ['BMW', '5', 'Series', '2013-2017', '530d', 'M', 'Sport']
# ['Mahindra', 'Scorpio', 'S4', 'Plus']
# ['Hyundai', 'Verna', '1.6', 'CRDi', 'SX']
# ['Audi', 'Q7', '3.0', 'TDI', 'Quattro', 'Premium', 'Plus']
# ['Chevrolet', 'Aveo', 'U-VA', '1.2', 'LT']
# ['Mahindra', 'Bolero', 'ZLX', 'BSIII']
# ['Hyundai', 'Xcent', '1.2', 'Kappa', 'S']
# ['Toyota', 'Innova', 'Crysta', '2.4', 'GX', 'MT', '8S']
# ['Hyundai', 'EON', 'Era', 'Plus']
# ['Volkswagen', 'Polo', 'Diesel', 'Comfortline', '1.2L']
# ['Maruti', 'Vitara', 'Brezza', 'ZDi']
# ['BMW', '3', 'Series', '320d', 'Prestige']
# ['Hyundai', 'EON', 'Sportz']
# ['Honda', 'City', '1.5', 'S', 'MT']
# ['Honda', 'Accord', '2.4', 'MT']
# ['Mahindra', 'Xylo', 'E8']
# ['BMW', '3', 'Series', '320d']
# ['Honda', 'City', 'V', 'MT']
# ['Mahindra', 'XUV500', 'W10', '2WD']
# ['Hyundai', 'i20', 'Asta', '1.4', 'CRDi']
# ['Toyota', 'Fortuner', '4x2', 'Manual']
# ['Mahindra', 'Bolero', 'DI', 'BSII']
# ['Maruti', 'Esteem', 'Vxi', '-', 'BSIII']
# ['Hyundai', 'Santro', 'LS', 'zipPlus']
# ['Mini', 'Cooper', '5', 'DOOR', 'D']
# ['Audi', 'Q3', '35', 'TDI', 'Quattro', 'Premium']
# ['Hyundai', 'i20', 'Sportz', 'Option']
# ['Tata', 'Safari', 'Storme', 'VX', 'Varicor', '400']
# ['Honda', 'BR-V', 'i-DTEC', 'VX', 'MT']
# ['Volkswagen', 'Jetta', '2013-2015', '2.0L', 'TDI', 'Highline']
# ['Hyundai', 'Xcent', '1.2', 'Kappa', 'S', 'Option']
# ['Maruti', 'Ignis', '1.2', 'Alpha']
# ['BMW', '5', 'Series', '2013-2017', '520d', 'Luxury', 'Line']
# ['Ford', 'Ikon', '1.3', 'CLXi']
# ['Hyundai', 'i10', 'Sportz']
# ['Hyundai', 'Verna', '1.6', 'CRDI']
# ['BMW', '3', 'Series', '320d', 'Highline']
# ['Mercedes-Benz', 'E-Class', '2009-2013', 'E200', 'CGI', 'Blue', 'Efficiency']
# ['Chevrolet', 'Beat', 'Option', 'Pack']
# ['Hyundai', 'Santro', 'Xing', 'XP']
# ['Tata', 'Indica', 'DLS']
# ['Mahindra', 'XUV500', 'W8', '2WD']
# ['Maruti', 'Ciaz', 'ZDi', 'Plus', 'SHVS']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '250', 'CDI', 'Avantgarde']
# ['Honda', 'City', 'ZX', 'CVT']
# ['Toyota', 'Fortuner', '4x2', '4', 'Speed', 'AT']
# ['Maruti', 'Alto', 'K10', 'VXI']
# ['Jaguar', 'XJ', '2.0L', 'Portfolio']
# ['Hyundai', 'i20', '1.4', 'Magna', 'ABS']
# ['Honda', 'BRV', 'i-VTEC', 'V', 'CVT']
# ['Toyota', 'Corolla', 'Executive', '(HE)']
# ['Audi', 'A6', '2011-2015', '2.0', 'TDI', 'Premium', 'Plus']
# ['Toyota', 'Innova', '2.5', 'ZX', 'Diesel', '7', 'Seater', 'BSIII']
# ['Hyundai', 'Grand', 'i10', 'CRDi', 'Sportz']
# ['Volkswagen', 'Vento', 'IPL', 'II', 'Petrol', 'Highline', 'AT']
# ['Toyota', 'Innova', '2.5', 'VX', '(Diesel)', '7', 'Seater', 'BS', 'IV']
# ['Hyundai', 'Verna', 'CRDi', 'SX']
# ['Maruti', 'Ritz', 'VDi']
# ['Audi', 'Q7', '3.0', 'TDI', 'Quattro', 'Technology']
# ['Hyundai', 'i20', 'Asta', 'Option', '1.2']
# ['Maruti', 'Vitara', 'Brezza', 'ZDi', 'Plus', 'Dual', 'Tone']
# ['Honda', 'City', 'i', 'VTEC', 'S']
# ['Maruti', 'Ciaz', 'ZXi']
# ['Nissan', 'Sunny', 'XV', 'CVT']
# ['Volkswagen', 'Polo', 'Diesel', 'Highline', '1.2L']
# ['Maruti', 'Ertiga', 'ZDI']
# ['Maruti', 'Swift', 'Dzire', 'VDI']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220', 'CDI', 'Elegance', 'AT']
# ['Honda', 'Brio', 'S', 'MT']
# ['Hyundai', 'i10', 'Magna', 'Optional', '1.1L']
# ['Hyundai', 'Verna', '1.6', 'SX', 'CRDi', '(O)']
# ['Maruti', 'Ciaz', 'VDI', 'SHVS']
# ['Ford', 'Ikon', '1.3', 'Flair']
# ['Volkswagen', 'Polo', '1.2', 'MPI', 'Highline']
# ['Honda', 'Jazz', '1.2', 'V', 'i', 'VTEC']
# ['Honda', 'Amaze', 'EX', 'i-Dtech']
# ['Hyundai', 'i20', 'Asta', '1.4', 'CRDi']
# ['Maruti', 'Ritz', 'VDi']
# ['Honda', 'City', 'V', 'MT']
# ['Skoda', 'Superb', '1.8', 'TSI', 'MT']
# ['Maruti', 'Vitara', 'Brezza', 'LDi', 'Option']
# ['Hyundai', 'i20', 'Asta']
# ['Maruti', 'Alto', 'K10', 'VXI', 'AGS']
# ['Hyundai', 'EON', 'Era', 'Plus']
# ['Hyundai', 'i10', 'Sportz']
# ['Mercedes-Benz', 'SLK-Class', 'SLK', '350']
# ['Audi', 'A6', '2.0', 'TDI', 'Design', 'Edition']
# ['Ford', 'EcoSport', '1.5', 'TDCi', 'Titanium']
# ['Volkswagen', 'Passat', 'Highline', 'DSG']
# ['Toyota', 'Innova', 'Crysta', '2.4', 'ZX', 'MT']
# ['Ford', 'Figo', 'Diesel', 'ZXI']
# ['Chevrolet', 'Aveo', '1.4']
# ['Maruti', 'Ritz', 'LXi']
# ['Land', 'Rover', 'Freelander', '2', 'SE']
# ['Hyundai', 'Grand', 'i10', 'Asta']
# ['Ford', 'Endeavour', '3.2', 'Trend', 'AT', '4X4']
# ['Audi', 'Q5', '2008-2012', '2.0', 'TDI']
# ['Hyundai', 'Verna', '1.6', 'VTVT']
# ['Mercedes-Benz', 'E-Class', '2015-2017', 'E250', 'CDI', 'Avantgarde']
# ['Mercedes-Benz', 'M-Class', 'ML', '350', '4Matic']
# ['Maruti', 'Swift', 'Dzire', 'ZXi']
# ['Honda', 'City', '1.3', 'EXI', 'S']
# ['Renault', 'Duster', '85PS', 'Diesel', 'RxL', 'Optional']
# ['Mercedes-Benz', 'New', 'C-Class', '220', 'CDI', 'AT']
# ['BMW', 'X5', 'xDrive', '30d', 'Design', 'Pure', 'Experience', '5', 'Seater']
# ['Hyundai', 'Xcent', '1.2', 'Kappa', 'SX', 'Option']
# ['Maruti', 'Dzire', 'AMT', 'ZXI', 'Plus']
# ['BMW', '3', 'Series', '320d', 'Corporate', 'Edition']
# ['Maruti', 'Alto', '800', 'LXI']
# ['Audi', 'A4', '2.0', 'TDI', '177', 'Bhp', 'Premium', 'Plus']
# ['Mini', 'Cooper', 'S']
# ['Audi', 'Q7', '3.0', 'TDI', 'Quattro', 'Premium', 'Plus']
# ['Chevrolet', 'Beat', 'Diesel', 'LT']
# ['Maruti', 'Wagon', 'R', 'LXI', 'BS', 'IV']
# ['Nissan', 'Terrano', 'XV', 'Premium', '110', 'PS']
# ['BMW', '3', 'Series', '320d', 'Luxury', 'Plus']
# ['Maruti', 'Swift', 'Dzire', 'VXI']
# ['Skoda', 'Yeti', 'Elegance', '4X2']
# ['Ford', 'EcoSport', '1.5', 'Ti', 'VCT', 'AT', 'Titanium']
# ['Hyundai', 'i20', '1.2', 'Magna']
# ['Maruti', 'S', 'Cross', 'DDiS', '200', 'Sigma', 'Option']
# ['Hyundai', 'Verna', 'Transform', 'VTVT']
# ['BMW', '3', 'Series', '320d', 'Luxury', 'Line']
# ['Hyundai', 'Grand', 'i10', '1.2', 'CRDi', 'Magna']
# ['Honda', 'City', 'i-VTEC', 'V']
# ['Maruti', 'Swift', '1.3', 'VXi']
# ['Maruti', 'Swift', 'VDI', 'BSIV']
# ['Maruti', 'Baleno', 'Zeta', '1.3']
# ['Tata', 'Safari', 'Storme', '2012-2015', 'LX']
# ['Hyundai', 'Accent', 'GLS']
# ['Maruti', 'Swift', 'LDI', 'SP', 'Limited', 'Edition']
# ['Maruti', 'Swift', 'VDI', 'BSIV']
# ['Tata', 'Nano', 'XTA']
# ['Maruti', 'Ertiga', 'VDI']
# ['Maruti', 'Celerio', 'VXI', 'AMT']
# ['Maruti', 'Swift', 'VDI', 'BSIV']
# ['Volkswagen', 'Vento', 'Petrol', 'Highline']
# ['Volkswagen', 'Jetta', '2007-2011', '1.9', 'Highline', 'TDI']
# ['Mini', 'Cooper', '5', 'DOOR', 'D']
# ['Tata', 'Indica', 'V2', 'DLS']
# ['Hyundai', 'Santro', 'Xing', 'XO']
# ['Land', 'Rover', 'Range', 'Rover', '3.0', 'D']
# ['Honda', 'City', 'i-VTEC', 'CVT', 'VX']
# ['Jaguar', 'XF', '2.2', 'Litre', 'Luxury']
# ['Mercedes-Benz', 'E-Class', '2015-2017', 'E250', 'Edition', 'E']
# ['Chevrolet', 'Cruze', 'LTZ']
# ['Mahindra', 'XUV500', 'W8', '2WD']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '200', 'CGI', 'Avantgarde']
# ['Honda', 'Jazz', 'VX']
# ['Toyota', 'Etios', 'G']
# ['Maruti', 'Alto', 'LXi', 'BSIII']
# ['Maruti', 'Swift', 'VXI', 'BSIV']
# ['Maruti', 'A-Star', 'Vxi']
# ['Tata', 'Nano', 'Lx', 'BSIV']
# ['Ford', 'Figo', 'Titanium', 'Diesel']
# ['Fiat', 'Linea', 'Emotion']
# ['Ford', 'Figo', 'Aspire', '1.2', 'Ti-VCT', 'Trend']
# ['Maruti', 'Baleno', 'LXI']
# ['BMW', '3', 'Series', '320d', 'Luxury', 'Line']
# ['Chevrolet', 'Cruze', 'LTZ']
# ['Mahindra', 'Scorpio', '2.6', 'DX']
# ['Tata', 'Indica', 'V2', 'eLS']
# ['Chevrolet', 'Cruze', 'LTZ', 'AT']
# ['Toyota', 'Innova', '2.5', 'V', 'Diesel', '8-seater']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220d', 'Avantgarde', 'Edition', 'C']
# ['Maruti', 'Ritz', 'VXi']
# ['Toyota', 'Innova', '2.5', 'GX', '(Diesel)', '8', 'Seater', 'BS', 'IV']
# ['Toyota', 'Fortuner', '4x4', 'MT']
# ['Hyundai', 'i10', 'Sportz', 'AT']
# ['Hyundai', 'Verna', '1.6', 'SX']
# ['Audi', 'Q3', '2012-2015', '35', 'TDI', 'Quattro', 'Premium', 'Plus']
# ['Chevrolet', 'Beat', 'LS']
# ['Ford', 'Fiesta', '1.4', 'Duratorq', 'ZXI']
# ['Ford', 'Figo', 'Diesel', 'EXI']
# ['Maruti', 'Celerio', 'VXI', 'AT']
# ['Mercedes-Benz', 'A', 'Class', 'A180', 'CDI']
# ['Hyundai', 'Creta', '1.6', 'SX']
# ['Maruti', 'Wagon', 'R', 'VXI', 'BS', 'IV']
# ['Mercedes-Benz', 'E-Class', '2009-2013', 'E', '220', 'CDI', 'Avantgarde']
# ['Ford', 'EcoSport', '1.5', 'Ti', 'VCT', 'MT', 'Titanium', 'BE']
# ['Renault', 'Koleos', '2.0', 'Diesel']
# ['Mahindra', 'XUV500', 'W10', '2WD']
# ['Maruti', 'Omni', 'E', '8', 'Str', 'STD']
# ['Maruti', 'Wagon', 'R', 'VXI']
# ['Ford', 'Endeavour', 'XLT', 'TDCi', '4X2']
# ['Hyundai', 'Verna', '1.6', 'SX']
# ['Hyundai', 'i20', 'Magna', '1.2']
# ['Maruti', 'Ertiga', 'ZXI']
# ['Mahindra', 'XUV500', 'W9', 'AT']
# ['Maruti', 'SX4', 'S', 'Cross', 'DDiS', '200', 'Zeta']
# ['Mercedes-Benz', 'SLK-Class', 'SLK', '350']
# ['Volkswagen', 'Polo', 'Diesel', 'Comfortline', '1.2L']
# ['Toyota', 'Fortuner', '4x4', 'MT']
# ['Mahindra', 'XUV500', 'W10', '2WD']
# ['Mercedes-Benz', 'GLE', '250d']
# ['Honda', 'Jazz', '1.2', 'VX', 'i', 'VTEC']
# ['Maruti', 'Swift', 'Dzire', 'VDI']
# ['Hyundai', 'Verna', '1.6', 'SX', 'VTVT']
# ['Ford', 'Endeavour', '3.2', 'Titanium', 'AT', '4X4']
# ['Hyundai', 'i20', '1.2', 'Asta', 'Option']
# ['Honda', 'City', '1.5', 'V', 'MT', 'Sunroof']
# ['Honda', 'Amaze', 'VX', 'Diesel']
# ['Hyundai', 'Verna', '1.6', 'SX', 'VTVT', '(O)']
# ['Honda', 'Mobilio', 'S', 'i', 'DTEC']
# ['Maruti', 'Ertiga', 'ZDI']
# ['Maruti', 'Alto', 'K10', 'LXI']
# ['Toyota', 'Qualis', 'FS', 'B2']
# ['Hyundai', 'i10', 'Sportz']
# ['Skoda', 'Laura', '1.9', 'TDI', 'AT', 'Ambiente']
# ['Hyundai', 'i20', 'Asta', 'Option', '1.2']
# ['BMW', '5', 'Series', '2003-2012', '530d', 'Highline']
# ['BMW', '3', 'Series', '320d', 'M', 'Sport']
# ['Chevrolet', 'Aveo', '1.4', 'LT', 'ABS', 'BSIV']
# ['Mercedes-Benz', 'E-Class', '2009-2013', 'E250', 'CDI', 'Elegance']
# ['Audi', 'A6', '2011-2015', '2.0', 'TDI', 'Premium', 'Plus']
# ['Maruti', 'Wagon', 'R', 'LXI', 'BS', 'IV']
# ['Renault', 'KWID', 'RXT']
# ['Volkswagen', 'Ameo', '1.5', 'TDI', 'Highline']
# ['Volkswagen', 'Polo', 'Diesel', 'Comfortline', '1.2L']
# ['Maruti', 'Alto', '800', 'LXI']
# ['Hyundai', 'i20', 'Asta', 'Option', '1.2']
# ['Toyota', 'Etios', 'Liva', 'G']
# ['Hyundai', 'i20', '1.2', 'Sportz']
# ['Hyundai', 'i20', '1.4', 'Asta']
# ['Maruti', 'Wagon', 'R', 'LXI', 'Optional']
# ['Hyundai', 'i20', '1.4', 'Asta', 'Option']
# ['Volkswagen', 'Polo', 'GT', 'TSI']
# ['Ford', 'Figo', 'Diesel', 'Titanium']
# ['Maruti', 'Swift', 'ZXI']
# ['Hyundai', 'Grand', 'i10', 'CRDi', 'Magna']
# ['Mahindra', 'Xylo', 'H4']
# ['Maruti', 'Alto', 'Green', 'LXi', '(CNG)']
# ['Hyundai', 'i10', 'Magna', '1.1']
# ['Skoda', 'Octavia', 'Elegance', '2.0', 'TDI', 'AT']
# ['BMW', 'X5', '2014-2019', 'xDrive', '30d', 'Design', 'Pure', 'Experience', '7', 'Seater']
# ['Maruti', 'Celerio', 'VXI', 'AT']
# ['Volkswagen', 'Vento', 'Diesel', 'Comfortline']
# ['BMW', '3', 'Series', '320d', 'Highline']
# ['Maruti', 'Ertiga', 'ZDI']
# ['Ford', 'Figo', 'Diesel', 'ZXI']
# ['Volkswagen', 'Polo', '1.2', 'MPI', 'Highline']
# ['Audi', 'A6', '3.0', 'TDI', 'quattro']
# ['Toyota', 'Innova', 'Crysta', '2.4', 'ZX', 'MT']
# ['Hyundai', 'Verna', '1.6', 'CRDi', 'EX', 'AT']
# ['Hyundai', 'Santro', 'Xing', 'GL', 'Plus']
# ['Audi', 'A4', '2.0', 'TDI']
# ['Audi', 'A4', '2.0', 'TDI']
# ['Skoda', 'Laura', '1.9', 'TDI', 'MT', 'Ambiente']
# ['Honda', 'CR-V', '2.0L', '2WD', 'AT']
# ['Hyundai', 'Verna', '1.6', 'SX', 'CRDi', '(O)']
# ['Honda', 'Mobilio', 'RS', 'i', 'DTEC']
# ['Hyundai', 'i20', '1.2', 'Asta', 'Option']
# ['Toyota', 'Innova', '2.5', 'G', '(Diesel)', '7', 'Seater', 'BS', 'IV']
# ['Hyundai', 'i20', 'Magna', '1.2']
# ['Mahindra', 'Bolero', 'VLX', 'BS', 'IV']
# ['Volkswagen', 'Vento', '1.5', 'TDI', 'Comfortline']
# ['Jaguar', 'XF', '2.2', 'Litre', 'Luxury']
# ['Maruti', 'Zen', 'LXi', '-', 'BS', 'III']
# ['Mercedes-Benz', 'E-Class', 'Facelift']
# ['Toyota', 'Fortuner', '3.0', 'Diesel']
# ['Hyundai', 'Grand', 'i10', 'AT', 'Asta']
# ['Hyundai', 'Xcent', '1.2', 'CRDi', 'S']
# ['Hyundai', 'Creta', '1.6', 'VTVT', 'S']
# ['Hyundai', 'i10', 'Sportz']
# ['Honda', 'Brio', 'S', 'MT']
# ['Toyota', 'Fortuner', '4x2', 'AT']
# ['Audi', 'A4', '2.0', 'TDI', 'Multitronic']
# ['Toyota', 'Innova', 'Crysta', '2.8', 'ZX', 'AT']
# ['Honda', 'City', 'i', 'DTEC', 'VX']
# ['Honda', 'City', 'i', 'DTEC', 'VX']
# ['Renault', 'KWID', '1.0', 'RXT', 'Optional']
# ['Maruti', 'Swift', 'DDiS', 'ZDI', 'Plus']
# ['Maruti', 'Celerio', 'VXI', 'Optional', 'AMT']
# ['Mahindra', 'XUV500', 'W8', '2WD']
# ['Hyundai', 'i10', 'Magna']
# ['Hyundai', 'i10', 'Magna', '1.1']
# ['Maruti', 'Dzire', 'VXI']
# ['Maruti', 'Grand', 'Vitara', 'AT']
# ['Audi', 'TT', '40', 'TFSI']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '200', 'CGI']
# ['Nissan', 'Sunny', '2011-2014', 'Diesel', 'XV']
# ['Maruti', 'Wagon', 'R', 'LXI']
# ['Maruti', 'Swift', 'Dzire', 'ZDI']
# ['Honda', 'Amaze', 'S', 'i-Dtech']
# ['Maruti', 'Swift', 'ZDI']
# ['Hyundai', 'Accent', 'Executive', 'CNG']
# ['Mahindra', 'Scorpio', 'LX', '2.6', 'Turbo']
# ['Mercedes-Benz', 'E-Class', 'E250', 'CDI', 'Avantgrade']
# ['Toyota', 'Fortuner', '4x2', 'Manual']
# ['Datsun', 'redi-GO', 'T', 'Option']
# ['Honda', 'City', 'V', 'MT']
# ['Toyota', 'Camry', 'Hybrid']
# ['Honda', 'City', 'i', 'DTec', 'V']
# ['Volkswagen', 'Jetta', '2012-2014', '2.0L', 'TDI', 'Trendline']
# ['Audi', 'A6', '2011-2015', '2.0', 'TDI']
# ['Maruti', 'Ertiga', 'VDI']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220', 'CDI', 'Style']
# ['Maruti', 'Swift', 'Dzire', 'Vdi', 'BSIV']
# ['Renault', 'Duster', '110PS', 'Diesel', 'RxZ', 'Pack']
# ['Maruti', 'Ritz', 'VDi']
# ['Maruti', 'Swift', 'Dzire', 'VXI']
# ['Maruti', 'Swift', 'ZDi']
# ['Hyundai', 'EON', 'Sportz']
# ['Maruti', 'Zen', 'VXI', 'BSII']
# ['Maruti', 'Eeco', '7', 'Seater', 'Standard']
# ['Audi', 'Q5', '30', 'TDI', 'quattro', 'Premium']
# ['Audi', 'Q3', '2.0', 'TDI']
# ['Smart', 'Fortwo', 'CDI', 'AT']
# ['Maruti', 'Swift', 'Dzire', 'VDi']
# ['Tata', 'Sumo', 'DX']
# ['BMW', 'X5', '2014-2019', 'xDrive', '30d', 'Design', 'Pure', 'Experience', '7', 'Seater']
# ['Honda', 'City', 'i-VTEC', 'CVT', 'VX']
# ['Tata', 'Indigo', 'eCS', 'eLX', 'BS', 'IV']
# ['Volkswagen', 'Vento', 'TSI']
# ['Maruti', 'Celerio', 'VXI']
# ['Toyota', 'Fortuner', '3.0', 'Diesel']
# ['Mitsubishi', 'Outlander', '2.4']
# ['Volkswagen', 'Jetta', '2007-2011', '1.9', 'Highline', 'TDI']
# ['Porsche', 'Cayman', '2009-2012', 'S']
# ['Hyundai', 'Creta', '1.6', 'CRDi', 'SX']
# ['Skoda', 'Fabia', '1.2', 'MPI', 'Ambiente', 'Petrol']
# ['Ford', 'EcoSport', '1.5', 'TDCi', 'Titanium']
# ['Maruti', 'Zen', 'Estilo', '1.1', 'LXI', 'BSIII']
# ['Maruti', 'Ciaz', '1.4', 'Delta']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '200', 'Avantgarde', 'Edition', 'C']
# ['Honda', 'Amaze', 'SX', 'i-VTEC']
# ['Toyota', 'Etios', 'GD']
# ['Renault', 'Duster', '85PS', 'Diesel', 'RxL']
# ['Maruti', 'Wagon', 'R', 'LXI', 'LPG', 'BSIV']
# ['Volkswagen', 'Polo', 'Petrol', 'Highline', '1.2L']
# ['Hyundai', 'Creta', '1.6', 'SX', 'Plus', 'Diesel']
# ['Jaguar', 'XF', 'Diesel']
# ['Jeep', 'Compass', '2.0', 'Limited', '4X4']
# ['Land', 'Rover', 'Range', 'Rover', 'Evoque', '2.0', 'TD4', 'HSE', 'Dynamic']
# ['Maruti', 'Baleno', 'Alpha', 'Diesel']
# ['Maruti', 'Ciaz', 'ZDi', 'SHVS']
# ['Maruti', 'SX4', 'Vxi', 'BSIII']
# ['Hyundai', 'Elantra', 'CRDi', 'SX']
# ['Mitsubishi', 'Pajero', 'Sport', '4X4']
# ['Volkswagen', 'Ameo', '1.2', 'MPI', 'Comfortline']
# ['Maruti', 'Ritz', 'VXi']
# ['Hyundai', 'Verna', 'CRDi', 'SX']
# ['Maruti', 'Swift', 'Dzire', 'Tour', 'LDI']
# ['Mahindra', 'KUV', '100', 'mFALCON', 'D75', 'K6']
# ['Toyota', 'Innova', 'Crysta', '2.4', 'ZX', 'MT']
# ['Maruti', 'Baleno', 'Delta', '1.2']
# ['Honda', 'Jazz', 'VX', 'Diesel']
# ['Hyundai', 'i20', '1.2', 'Asta']
# ['Hyundai', 'i20', 'Sportz', 'Diesel']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220d', 'Avantgarde', 'Edition', 'C']
# ['Hyundai', 'Xcent', '1.2', 'Kappa', 'Base']
# ['Hyundai', 'Grand', 'i10', 'AT', 'Asta']
# ['Maruti', 'Alto', '800', 'VXI']
# ['Chevrolet', 'Sail', 'Hatchback', '1.2', 'LS']
# ['Mercedes-Benz', 'C-Class', 'Progressive', 'C', '220d']
# ['Skoda', 'Superb', 'Elegance', '1.8', 'TSI', 'AT']
# ['Audi', 'A4', '2.0', 'TDI']
# ['Toyota', 'Innova', '2.5', 'G', '(Diesel)', '7', 'Seater', 'BS', 'IV']
# ['Mercedes-Benz', 'CLA', '200', 'CDI', 'Sport']
# ['Hyundai', 'i10', 'Era']
# ['Maruti', 'Swift', 'Dzire', 'VXi']
# ['Skoda', 'Rapid', '1.5', 'TDI', 'AT', 'Ambition']
# ['Maruti', 'Ritz', 'VDi']
# ['Hyundai', 'Accent', 'GLS', '1.6']
# ['Honda', 'Amaze', 'SX', 'i-VTEC']
# ['Maruti', 'Wagon', 'R', 'LXI']
# ['Volkswagen', 'Polo', 'Diesel', 'Comfortline', '1.2L']
# ['Ford', 'Endeavour', '2.2', 'Trend', 'AT', '4X2']
# ['Hyundai', 'i20', '1.2', 'Sportz']
# ['Chevrolet', 'Beat', 'Diesel', 'PS']
# ['Honda', 'Civic', '2010-2013', '1.8', 'V', 'MT']
# ['Maruti', 'Wagon', 'R', 'VXI', 'BS', 'IV']
# ['Skoda', 'Rapid', '1.6', 'MPI', 'Ambition', 'Plus']
# ['Maruti', 'Baleno', 'Vxi', '-', 'BSIII']
# ['Ford', 'EcoSport', '1.5', 'TDCi', 'Titanium']
# ['Hyundai', 'Accent', 'GLE']
# ['BMW', '5', 'Series', '520d', 'Luxury', 'Line']
# ['Maruti', 'Alto', 'K10', '2010-2014', 'VXI']
# ['Audi', 'Q3', '2012-2015', '2.0', 'TDI', 'Quattro', 'Premium', 'Plus']
# ['Maruti', 'Wagon', 'R', 'LXI', 'DUO', 'BSIII']
# ['Toyota', 'Corolla', 'H4']
# ['Volvo', 'XC60', 'D5']
# ['Honda', 'Jazz', '1.5', 'VX', 'i', 'DTEC']
# ['Maruti', 'Ciaz', '1.3', 'Alpha']
# ['Maruti', 'Swift', 'VXI', 'BSIV']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220', 'CDI', 'Avantgarde']
# ['Maruti', 'Wagon', 'R', 'VXI', 'Minor']
# ['Mercedes-Benz', 'A', 'Class', 'A180', 'Sport']
# ['Hyundai', 'Santro', 'Xing', 'GL']
# ['Maruti', 'Swift', 'Dzire', 'AMT', 'ZDI']
# ['Hyundai', 'Grand', 'i10', 'AT', 'Asta']
# ['Nissan', 'Sunny', '2011-2014', 'XV', 'Special', 'Edition']
# ['Maruti', 'A-Star', 'Lxi']
# ['Renault', 'KWID', 'RXT', 'Optional']
# ['Hyundai', 'Verna', '1.6', 'SX', 'VTVT', '(O)', 'AT']
# ['Maruti', 'Wagon', 'R', 'LXI', 'Minor']
# ['BMW', '3', 'Series', '320d', 'Sport', 'Line']
# ['BMW', '5', 'Series', '2003-2012', '520d']
# ['Tata', 'Indigo', 'CS', 'eVX']
# ['Hyundai', 'i20', 'Sportz', '1.4', 'CRDi']
# ['Maruti', 'Omni', 'E', 'MPI', 'STD', 'BS', 'IV']
# ['Maruti', 'Swift', 'ZDi']
# ['Ford', 'Ecosport', 'Signature', 'Edition', 'Diesel']
# ['Honda', 'Brio', 'VX', 'AT']
# ['Toyota', 'Innova', 'Crysta', '2.4', 'GX', 'MT']
# ['Mahindra', 'Scorpio', '2.6', 'LX']
# ['Hyundai', 'i20', '1.2', 'Magna']
# ['Hyundai', 'Verna', '1.6', 'SX']
# ['Mahindra', 'XUV500', 'W6', '2WD']
# ['Volkswagen', 'Vento', '1.5', 'TDI', 'Comfortline']
# ['Maruti', 'Swift', 'Dzire', 'VDI', 'Optional']
# ['Tata', 'Manza', 'Aura', 'Safire', 'BS', 'IV']
# ['Maruti', 'Swift', 'VDI']
# ['Volkswagen', 'Polo', 'Diesel', 'Highline', '1.2L']
# ['Honda', 'City', '1.5', 'V', 'MT']
# ['Hyundai', 'i20', 'Asta', '(o)', '1.4', 'CRDi', '(Diesel)']
# ['Honda', 'City', '1.5', 'V', 'MT']
# ['Chevrolet', 'Beat', 'Diesel']
# ['Chevrolet', 'Spark', '1.0', 'LS']
# ['Tata', 'New', 'Safari', 'DICOR', '2.2', 'EX', '4x2']
# ['Mercedes-Benz', 'GL-Class', '350', 'CDI', 'Blue', 'Efficiency']
# ['BMW', '5', 'Series', '2003-2012', '530d', 'Highline']
# ['Toyota', 'Fortuner', '2.8', '4WD', 'MT']
# ['BMW', 'X1', 'sDrive', '18i']
# ['Renault', 'Captur', '1.5', 'Diesel', 'Platine', 'Mono']
# ['Hyundai', 'Xcent', '1.1', 'CRDi', 'S']
# ['BMW', '3', 'Series', '320d']
# ['BMW', '5', 'Series', '2010-2013', '525i']
# ['Nissan', 'Micra', 'XE']
# ['Jaguar', 'XF', '2.2', 'Litre', 'Luxury']
# ['Land', 'Rover', 'Range', 'Rover', 'TDV8', '(Diesel)']
# ['Jeep', 'Compass', '1.4', 'Limited', 'Option']
# ['Honda', 'CR-V', '2.4', 'AT']
# ['Maruti', 'Swift', 'VXI']
# ['Hyundai', 'Xcent', '1.1', 'CRDi', 'S']
# ['Nissan', 'Terrano', 'XV', 'Premium', '110', 'PS']
# ['Audi', 'A4', '35', 'TDI', 'Technology']
# ['Hyundai', 'Grand', 'i10', 'Asta', 'Option']
# ['Toyota', 'Innova', '2.5', 'G', '(Diesel)', '8', 'Seater']
# ['Hyundai', 'i20', '1.2', 'Magna']
# ['Ford', 'EcoSport', '1.5', 'TDCi', 'Titanium']
# ['Honda', 'City', '1.5', 'S', 'MT']
# ['Ford', 'EcoSport', '1.5', 'Petrol', 'Titanium', 'Plus', 'AT']
# ['Volkswagen', 'Polo', 'Diesel', 'Highline', '1.2L']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220', 'CDI', 'Avantgarde']
# ['Ford', 'Ecosport', '1.5', 'DV5', 'MT', 'Titanium']
# ['Tata', 'Indigo', 'GLE']
# ['Maruti', 'Swift', 'Dzire', 'LDI']
# ['Maruti', 'S-Cross', 'Zeta', 'DDiS', '200', 'SH']
# ['Renault', 'Duster', '110PS', 'Diesel', 'RxZ', 'Pack']
# ['Maruti', 'Wagon', 'R', 'VXI']
# ['Hyundai', 'Santro', 'Xing', 'GL']
# ['Chevrolet', 'Beat', 'Diesel', 'LT']
# ['Mahindra', 'XUV500', 'W4', '1.99', 'mHawk']
# ['Hyundai', 'i10', 'Era', '1.1']
# ['Tata', 'New', 'Safari', 'DICOR', '2.2', 'EX', '4x4']
# ['Hyundai', 'i10', 'Sportz']
# ['Toyota', 'Innova', 'Crysta', '2.8', 'ZX', 'AT']
# ['Skoda', 'Laura', 'Elegance', 'MT']
# ['Hyundai', 'Grand', 'i10', 'Sportz']
# ['Toyota', 'Etios', 'Liva', 'GD']
# ['Maruti', 'Swift', 'Dzire', 'VDI']
# ['Hyundai', 'i20', 'Asta', '1.4', 'CRDi', '(Diesel)']
# ['Ford', 'Figo', '2015-2019', '1.5D', 'Trend', 'MT']
# ['Maruti', 'Ertiga', 'VDI']
# ['Maruti', 'Ertiga', 'ZDI']
# ['Honda', 'City', '1.5', 'V', 'AT', 'Sunroof']
# ['Maruti', 'Alto', 'LXi', 'BSIII']
# ['Ford', 'Endeavour', '3.2', 'Titanium', 'AT', '4X4']
# ['Maruti', 'Vitara', 'Brezza', 'ZDi', 'Plus']
# ['Porsche', 'Boxster', 'S', 'tiptronic']
# ['Maruti', 'Swift', 'ZDi']
# ['Tata', 'Zest', 'Revotron', '1.2', 'XT']
# ['Hyundai', 'i20', '1.2', 'Sportz', 'Option']
# ['Skoda', 'Fabia', '1.4', 'TDI', 'Active']
# ['Toyota', 'Corolla', 'Altis', 'D-4D', 'J']
# ['Volkswagen', 'Ameo', '1.2', 'MPI', 'Comfortline']
# ['Hyundai', 'Creta', '1.6', 'VTVT', 'S']
# ['Hyundai', 'i10', 'Magna', '1.2']
# ['Chevrolet', 'Beat', 'LS']
# ['Jaguar', 'XF', '3.0', 'Litre', 'S', 'Premium', 'Luxury']
# ['Nissan', 'Terrano', 'XL']
# ['Audi', 'Q3', '2012-2015', '2.0', 'TDI', 'Quattro', 'Premium', 'Plus']
# ['Hyundai', 'i10', 'Asta', 'AT']
# ['Maruti', 'Alto', 'K10', 'VXI', 'AGS']
# ['Audi', 'Q7', '4.2', 'TDI', 'Quattro', 'Technology']
# ['Maruti', 'Vitara', 'Brezza', 'VDi']
# ['Hyundai', 'EON', 'D', 'Lite', 'Plus']
# ['Mahindra', 'XUV300', 'W8', 'Diesel']
# ['Hyundai', 'Verna', 'CRDi', '1.6', 'SX', 'Option']
# ['Maruti', 'Wagon', 'R', 'VXI']
# ['Hyundai', 'i20', 'Sportz', 'Option']
# ['Honda', 'City', 'i', 'VTEC', 'V']
# ['Toyota', 'Innova', '2.5', 'V', 'Diesel', '7-seater']
# ['Hyundai', 'Verna', 'CRDi', 'SX']
# ['Tata', 'Hexa', 'XT']
# ['Audi', 'Q7', '3.0', 'TDI', 'Quattro', 'Premium', 'Plus']
# ['Maruti', 'Wagon', 'R', 'VXI']
# ['BMW', '5', 'Series', '2013-2017', '525d', 'Luxury', 'Line']
# ['Honda', 'Amaze', 'EX', 'i-Vtech']
# ['Maruti', 'Alto', '800', '2016-2019', 'LXI']
# ['Hyundai', 'Verna', '1.6', 'SX', 'VTVT']
# ['Tata', 'Tiago', '1.2', 'Revotron', 'XZ']
# ['Maruti', 'Swift', 'LXI']
# ['Hyundai', 'EON', 'Era']
# ['Mercedes-Benz', 'E-Class', 'E', '220', 'd']
# ['Hyundai', 'i20', 'Magna', '1.4', 'CRDi']
# ['Toyota', 'Etios', 'VD']
# ['Toyota', 'Corolla', 'Altis', 'Diesel', 'D4DG']
# ...
# ['Hyundai', 'i20', '1.2', 'Asta']
# ['Maruti', 'Wagon', 'R', 'VXI', '1.2']
# ['Mahindra', 'Scorpio', 'VLS', '2.2', 'mHawk']
# ['Maruti', 'Wagon', 'R', 'LXI']
# ['Maruti', 'Ciaz', 'VDi']
# ['Audi', 'A4', '35', 'TDI', 'Premium', 'Plus']
# ['Maruti', 'Ciaz', '1.4', 'Zeta']
# ['Ford', 'Freestyle', 'Titanium', 'Plus', 'Diesel']
# ['Toyota', 'Etios', 'GD']
# ['Mahindra', 'XUV500', 'W8', '4WD']
# ['Chevrolet', 'Cruze', 'LTZ']
# ['Hyundai', 'EON', 'D', 'Lite', 'Plus', 'Option']
# ['Maruti', 'Ritz', 'VDi']
# ['Toyota', 'Etios', 'Liva', 'GD']
# ['Maruti', 'Wagon', 'R', 'VXI']
# ['Ford', 'EcoSport', '1.5', 'Ti', 'VCT', 'MT', 'Titanium']
# ['Renault', 'Duster', '110PS', 'Diesel', 'RxZ', 'AMT']
# ['Maruti', 'Swift', 'VVT', 'ZXI']
# ['Mahindra', 'Xylo', 'D4']
# ['Toyota', 'Etios', 'Liva', 'V']
# ['Honda', 'CR-V', '2.4', 'AT']
# ['Fiat', 'Punto', 'EVO', '1.3', 'Emotion']
# ['Hyundai', 'Creta', '1.6', 'CRDi', 'AT', 'SX', 'Plus']
# ['Fiat', 'Abarth', '595', 'Competizione']
# ['Ford', 'Ecosport', '1.0', 'Ecoboost', 'Platinum', 'Edition']
# ['Jaguar', 'XF', '3.0', 'Litre', 'S', 'Premium', 'Luxury']
# ['Hyundai', 'Grand', 'i10', 'Sportz']
# ['Mercedes-Benz', 'M-Class', 'ML', '320', 'CDI']
# ['Toyota', 'Innova', '2.5', 'V', 'Diesel', '7-seater']
# ['Honda', 'Accord', '2.4', 'AT']
# ['Maruti', 'Wagon', 'R', 'LXI']
# ['Hyundai', 'i20', '1.4', 'CRDi', 'Magna']
# ['Maruti', 'Swift', 'VXI']
# ['Honda', 'City', '1.5', 'E', 'MT']
# ['Volkswagen', 'Polo', '1.2', 'MPI', 'Comfortline']
# ['Hyundai', 'Accent', 'Executive', 'LPG']
# ['ISUZU', 'D-MAX', 'V-Cross', '4X4']
# ['Honda', 'BR-V', 'i-VTEC', 'VX', 'MT']
# ['Maruti', 'Swift', 'Dzire', 'Tour', 'LDI']
# ['Honda', 'Mobilio', 'V', 'i', 'DTEC']
# ['Maruti', 'Ertiga', 'VXI']
# ['Mitsubishi', 'Pajero', 'Sport', '4X2', 'AT']
# ['Mercedes-Benz', 'B', 'Class', '2012-2015', 'B200', 'Sport', 'CDI']
# ['Maruti', 'Eeco', '5', 'STR', 'With', 'AC', 'Plus', 'HTR', 'CNG']
# ['Volkswagen', 'Vento', '1.6', 'Trendline']
# ['Maruti', 'Versa', 'DX2']
# ['Honda', 'City', 'i', 'DTEC', 'SV']
# ['Maruti', 'Swift', 'Dzire', '1.2', 'Lxi', 'BSIV']
# ['Volkswagen', 'Vento', 'Diesel', 'Trendline']
# ['Skoda', 'Laura', '1.9', 'TDI', 'AT', 'Ambiente']
# ['Honda', 'Brio', 'V', 'MT']
# ['Maruti', 'A-Star', 'Vxi']
# ['Maruti', 'SX4', 'VDI']
# ['Hyundai', 'Elantra', '1.6', 'SX']
# ['Maruti', 'Alto', 'K10', 'LXI']
# ['Maruti', 'Alto', 'LX']
# ['Datsun', 'redi-GO', 'T', 'Option']
# ['Ford', 'Ecosport', '1.5', 'DV5', 'MT', 'Titanium', 'Optional']
# ['Honda', 'City', 'i', 'DTec', 'SV']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '250', 'CDI', 'Elegance']
# ['Hyundai', 'Sonata', 'Embera', '2.4L', 'MT']
# ['Chevrolet', 'Spark', '1.0', 'LS']
# ['Volkswagen', 'Polo', '1.2', 'MPI', 'Highline']
# ['Hyundai', 'i10', 'Sportz', '1.2']
# ['Toyota', 'Etios', 'Liva', 'G']
# ['Maruti', 'Alto', 'K10', 'VXI']
# ['Honda', 'CR-V', '2.4', 'AT']
# ['Hyundai', 'Verna', '1.6', 'VTVT', 'EX', 'AT']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '250', 'CDI', 'Elegance']
# ['Honda', 'Amaze', 'VX', 'CVT', 'i-VTEC']
# ['Mahindra', 'Xylo', 'E8']
# ['Hyundai', 'Sonata', 'Transform', '2.4', 'GDi', 'AT']
# ['Hyundai', 'Creta', '1.4', 'CRDi', 'S', 'Plus']
# ['Toyota', 'Innova', '2.5', 'G4', 'Diesel', '7-seater']
# ['Honda', 'Jazz', '2020', 'Petrol']
# ['Maruti', 'Alto', '800', 'CNG', 'LXI']
# ['Hyundai', 'i20', 'Magna', '1.2']
# ['Mercedes-Benz', 'SLC', '43', 'AMG']
# ['Hyundai', 'i20', '1.4', 'Sportz']
# ['Toyota', 'Fortuner', '4x2', '4', 'Speed', 'AT']
# ['Mahindra', 'Scorpio', 'VLX', '2WD', 'Airbag', 'BSIII']
# ['Mercedes-Benz', 'GLE', '350d']
# ['Volkswagen', 'Polo', '1.2', 'MPI', 'Highline']
# ['BMW', '5', 'Series', '2003-2012', '520d']
# ['Ford', 'Ecosport', '1.5', 'DV5', 'MT', 'Ambiente']
# ['Maruti', 'SX4', 'Zxi', 'BSIII']
# ['Hyundai', 'i20', '1.4', 'Asta', 'AT', '(O)', 'with', 'Sunroof']
# ['Hyundai', 'Xcent', '1.1', 'CRDi', 'S']
# ['Renault', 'Lodgy', '110PS', 'RxL']
# ['Renault', 'Duster', '110PS', 'Diesel', 'RxZ']
# ['Maruti', 'Swift', 'Dzire', 'VXi']
# ['Honda', 'City', 'i', 'DTec', 'VX']
# ['Audi', 'A4', '3.0', 'TDI', 'Quattro', 'Premium']
# ['Mercedes-Benz', 'E-Class', '250', 'D', 'W', '124']
# ['Toyota', 'Innova', '2.5', 'LE', '2014', 'Diesel', '8', 'Seater']
# ['Volkswagen', 'Jetta', '2007-2011', '2.0', 'TDI', 'Trendline']
# ['Mahindra', 'Bolero', 'ZLX']
# ['Maruti', 'Swift', 'Dzire', 'VXI']
# ['Honda', 'City', '1.5', 'V', 'MT']
# ['Hyundai', 'Grand', 'i10', '1.2', 'CRDi', 'Sportz']
# ['Tata', 'Indigo', 'CS', 'eVX']
# ['Maruti', 'Baleno', 'Zeta', '1.3']
# ['Maruti', 'Alto', '800', '2016-2019', 'LXI']
# ['Mercedes-Benz', 'E-Class', 'E240', 'V6', 'AT']
# ['Maruti', 'Swift', 'Dzire', 'Vdi', 'BSIV']
# ['Nissan', 'Terrano', 'XE', '85', 'PS']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '200', 'CGI']
# ['Maruti', 'Celerio', 'VXI']
# ['Hyundai', 'Santro', 'Xing', 'GLS']
# ['Volkswagen', 'Polo', '1.2', 'MPI', 'Highline']
# ['Mahindra', 'Bolero', 'ZLX']
# ['BMW', '5', 'Series', '2013-2017', '530d', 'M', 'Sport']
# ['Honda', 'City', '1.5', 'V', 'MT', 'Sunroof']
# ['Hyundai', 'i20', 'Sportz', '1.2']
# ['Toyota', 'Innova', '2.5', 'GX', '(Diesel)', '8', 'Seater', 'BS', 'IV']
# ['BMW', '5', 'Series', '2007-2010', '525d', 'Sedan']
# ['Volkswagen', 'Polo', 'GT', 'TSI']
# ['Mitsubishi', 'Pajero', 'Sport', '4X2', 'AT']
# ['Maruti', 'Ertiga', 'VXI']
# ['Audi', 'A6', '2011-2015', '2.0', 'TDI', 'Technology']
# ['Maruti', 'Swift', 'Dzire', 'VDI']
# ['Toyota', 'Fortuner', '3.0', 'Diesel']
# ['Hyundai', 'i10', 'Sportz', '1.1L']
# ['Mahindra', 'TUV', '300', '2015-2019', 'T8', 'AMT']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220', 'CDI', 'CLASSIC']
# ['Maruti', 'Swift', 'Dzire', 'Ldi', 'BSIV']
# ['Hyundai', 'i20', 'Magna']
# ['Maruti', 'Swift', 'VDI', 'BSIV']
# ['Toyota', 'Innova', 'Crysta', '2.4', 'VX', 'MT', '8S']
# ['Toyota', 'Etios', 'V']
# ['Toyota', 'Corolla', 'Altis', 'Diesel', 'D4DG']
# ['Hyundai', 'Grand', 'i10', '1.2', 'CRDi', 'Magna']
# ['Maruti', 'SX4', 'ZDI']
# ['Audi', 'A6', '2011-2015', '35', 'TDI', 'Premium']
# ['Honda', 'Amaze', 'S', 'i-Vtech']
# ['Hyundai', 'i20', 'Magna', '1.2']
# ['Mahindra', 'XUV500', 'W6', '2WD']
# ['Mercedes-Benz', 'E-Class', '2015-2017', 'E250', 'CDI', 'Avantgarde']
# ['Hyundai', 'Verna', '1.4', 'CRDi']
# ['Honda', 'Amaze', 'EX', 'i-Vtech']
# ['Audi', 'A4', '2.0', 'TDI', 'Premium', 'Sport', 'Limited', 'Edition']
# ['Hyundai', 'i10', 'Magna']
# ['Tata', 'Tigor', '1.2', 'Revotron', 'XT']
# ['Hyundai', 'Xcent', '1.1', 'CRDi', 'S']
# ['Ford', 'Figo', 'Diesel', 'ZXI']
# ['Toyota', 'Innova', '2.5', 'GX', '(Diesel)', '7', 'Seater']
# ['Hyundai', 'i20', '2015-2017', '1.4', 'CRDi', 'Sportz']
# ['Mercedes-Benz', 'E-Class', 'E250', 'CDI', 'Launch', 'Edition']
# ['Hyundai', 'Creta', '1.6', 'SX', 'Plus', 'Diesel']
# ['Chevrolet', 'Spark', '1.0', 'LT']
# ['Hyundai', 'i20', '1.4', 'CRDi', 'Sportz']
# ['Maruti', 'Swift', 'Dzire', 'VDI']
# ['Hyundai', 'i10', 'Magna', '1.2']
# ['Hyundai', 'Santro', 'Xing', 'GLS']
# ['Ford', 'Ecosport', '1.5', 'DV5', 'MT', 'Ambiente']
# ['Ford', 'Fiesta', 'Classic', '1.4', 'Duratorq', 'CLXI']
# ['Hyundai', 'Creta', '1.6', 'CRDi', 'AT', 'SX', 'Plus']
# ['Hyundai', 'Creta', '1.6', 'VTVT', 'Base']
# ['Honda', 'City', '1.5', 'V', 'MT']
# ['Maruti', 'Ignis', '1.2', 'AMT', 'Delta']
# ['Honda', 'City', 'i-VTEC', 'CVT', 'ZX']
# ['Honda', 'City', '1.5', 'V', 'MT']
# ['Ford', 'Fiesta', 'Classic', '1.6', 'Duratec', 'LXI']
# ['Hyundai', 'i20', 'Sportz', '1.2']
# ['Toyota', 'Corolla', 'Executive', '(HE)']
# ['Nissan', 'Micra', 'Diesel', 'XV']
# ['Maruti', 'Alto', 'LXi', 'BSIII']
# ['Maruti', 'Ciaz', 'VDi', 'Plus']
# ['Maruti', 'Ciaz', '1.3', 'Alpha']
# ['Mahindra', 'XUV500', 'W8', '2WD']
# ['Renault', 'Duster', '85PS', 'Diesel', 'RxL']
# ['Hyundai', 'i20', '1.2', 'Sportz']
# ['Renault', 'Pulse', 'RxL']
# ['Maruti', 'Wagon', 'R', 'AMT', 'VXI']
# ['BMW', '6', 'Series', '650i', 'Coupe']
# ['Honda', 'City', 'V', 'MT']
# ['Tata', 'Indigo', 'eCS', 'LX', 'BSIV']
# ['Honda', 'Brio', 'S', 'MT']
# ['Honda', 'Jazz', '1.5', 'S', 'i', 'DTEC']
# ['Mercedes-Benz', 'A', 'Class', 'A180', 'CDI']
# ['Toyota', 'Corolla', 'Altis', 'GL']
# ['Honda', 'Civic', '2006-2010', '1.8', '(E)', 'MT']
# ['Hyundai', 'Creta', '1.6', 'CRDi', 'SX', 'Option']
# ['Audi', 'Q5', '2008-2012', '2.0', 'TFSI', 'Quattro']
# ['OpelCorsa', '1.4Gsi']
# ['Toyota', 'Fortuner', '4x2', 'AT']
# ['Hyundai', 'Creta', '1.6', 'VTVT', 'S']
# ['Volkswagen', 'Ameo', '1.5', 'TDI', 'Highline']
# ['Hyundai', 'i20', 'Magna']
# ['Audi', 'A6', '2011-2015', '2.0', 'TDI', 'Premium', 'Plus']
# ['Hyundai', 'Grand', 'i10', 'CRDi', 'Sportz']
# ['Audi', 'Q3', '30', 'TDI', 'S', 'Edition']
# ['BMW', '5', 'Series', '2013-2017', '530d', 'M', 'Sport']
# ['Maruti', 'Swift', 'Dzire', 'AMT', 'ZDI']
# ['Hyundai', 'Grand', 'i10', '1.2', 'Kappa', 'Sportz', 'AT']
# ['Honda', 'City', 'i', 'DTEC', 'SV']
# ['Hyundai', 'Grand', 'i10', '1.2', 'Kappa', 'Magna']
# ['Honda', 'Jazz', '1.2', 'V', 'CVT', 'i', 'VTEC']
# ['Maruti', 'Swift', 'VDi', 'BSIII', 'W/', 'ABS']
# ['Maruti', 'Wagon', 'R', 'VXI']
# ['Maruti', 'Ciaz', 'RS', 'ZDi', 'Plus', 'SHVS']
# ['Volkswagen', 'Vento', '1.2', 'TSI', 'Comfortline', 'AT']
# ['Maruti', 'Swift', 'VXI', 'BSIV']
# ['Skoda', 'Laura', 'Ambition', '2.0', 'TDI', 'CR', 'AT']
# ['Hyundai', 'Xcent', '1.1', 'CRDi', 'S', 'Celebration', 'Edition']
# ['Hyundai', 'Creta', '1.6', 'CRDi', 'SX']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '200', 'CGI', 'Elegance']
# ['Maruti', 'Swift', 'VDI']
# ['Toyota', 'Etios', 'G']
# ['Hyundai', 'Santro', 'Xing', 'XG', 'AT', 'eRLX', 'Euro', 'III']
# ['Maruti', 'Swift', 'Dzire', 'VXI', 'Optional']
# ['Audi', 'Q5', '3.0', 'TDI', 'Quattro', 'Technology']
# ['Honda', 'City', 'V', 'MT']
# ['Mahindra', 'KUV', '100', 'mFALCON', 'D75', 'K6', '5str', 'AW']
# ['Mahindra', 'Xylo', 'D4', 'BSIV']
# ['Tata', 'Tiago', '1.2', 'Revotron', 'XT']
# ['Mahindra', 'Scorpio', 'VLX', '2WD', 'BSIII']
# ['Toyota', 'Innova', 'Crysta', '2.8', 'GX', 'AT']
# ['Maruti', 'Wagon', 'R', 'VXI', 'BSIII']
# ['Maruti', '800', 'AC']
# ['Honda', 'Civic', '2006-2010', '1.8', 'MT', 'Sport']
# ['Chevrolet', 'Beat', 'Diesel', 'LS']
# ['Mahindra', 'Thar', 'CRDe']
# ['Tata', 'Zest', 'Revotron', '1.2T', 'XE']
# ['Hyundai', 'EON', 'Era', 'Plus']
# ['Mahindra', 'Ssangyong', 'Rexton', 'RX7']
# ['Hyundai', 'Creta', '1.6', 'CRDi', 'SX', 'Option']
# ['Tata', 'Zest', 'Quadrajet', '1.3', '75PS', 'XE']
# ['Chevrolet', 'Enjoy', 'Petrol', 'LTZ', '7', 'Seater']
# ['Skoda', 'Superb', 'Elegance', '2.0', 'TDI', 'CR', 'AT']
# ['Hyundai', 'i20', '2015-2017', 'Magna', 'Optional', '1.4', 'CRDi']
# ['Audi', 'Q3', '2012-2015', '2.0', 'TDI', 'Quattro', 'Premium', 'Plus']
# ['Mahindra', 'Scorpio', 'S6', 'Plus', '7', 'Seater']
# ['BMW', '3', 'Series', '320d']
# ['Mercedes-Benz', 'CLA', '45', 'AMG']
# ['Honda', 'City', '1.5', 'S', 'MT']
# ['Maruti', 'Vitara', 'Brezza', 'ZDi']
# ['Toyota', 'Camry', '2.5', 'G']
# ['Maruti', 'Swift', 'Vdi', 'BSIII']
# ['Hyundai', 'Elantra', 'SX', 'AT']
# ['Renault', 'Duster', '85PS', 'Diesel', 'RxL', 'Optional']
# ['Audi', 'Q5', '2008-2012', '3.0', 'TDI', 'Quattro']
# ['Maruti', 'Esteem', 'Vxi', '-', 'BSIII']
# ['Jeep', 'Compass', '2.0', 'Longitude']
# ['Honda', 'City', '1.5', 'V', 'AT']
# ['Tata', 'Zest', 'Quadrajet', '1.3', '75PS', 'XE']
# ['Maruti', 'Baleno', 'Zeta', '1.2']
# ['Maruti', 'Swift', 'Dzire', 'VDI']
# ['Volkswagen', 'Polo', '1.2', 'MPI', 'Highline']
# ['Mini', 'Clubman', 'Cooper', 'S']
# ['Mitsubishi', 'Pajero', 'Sport', '4X2', 'AT']
# ['Honda', 'City', 'ZX', 'EXi']
# ['Hyundai', 'EON', 'Era', 'Plus']
# ['Chevrolet', 'Spark', '1.0', 'PS']
# ['Maruti', 'Alto', 'LXi']
# ['Toyota', 'Corolla', 'Executive', '(HE)']
# ['Hyundai', 'i20', '1.2', 'Sportz', 'Option']
# ['Hyundai', 'Verna', '1.4', 'CRDi']
# ['Chevrolet', 'Enjoy', '1.4', 'LTZ', '8']
# ['Fiat', 'Grande', 'Punto', '1.4', 'Emotion']
# ['Mahindra', 'XUV500', 'W8', '4WD']
# ['Maruti', 'Vitara', 'Brezza', 'ZDi', 'AMT']
# ['Toyota', 'Etios', 'Liva', 'G']
# ['Hyundai', 'Creta', '1.6', 'CRDi', 'SX']
# ['Hyundai', 'Santro', 'Xing', 'GLS']
# ['Hyundai', 'i20', '1.4', 'Asta', '(AT)']
# ['Hyundai', 'Elantra', 'CRDi']
# ['Mahindra', 'XUV500', 'W10', '2WD']
# ['Audi', 'A6', '2.0', 'TDI', 'Design', 'Edition']
# ['Tata', 'Tiago', '1.2', 'Revotron', 'XZ', 'WO', 'Alloy']
# ['Mercedes-Benz', 'A', 'Class', 'Edition', '1']
# ['Hyundai', 'Verna', '1.6', 'SX', 'VTVT', '(O)', 'AT']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220d', 'Avantgarde', 'Edition', 'C']
# ['BMW', '7', 'Series', '740i', 'Sedan']
# ['Land', 'Rover', 'Range', 'Rover', '2.2L', 'Pure']
# ['Hyundai', 'Creta', '1.6', 'SX', 'Plus', 'Petrol', 'Automatic']
# ['Volkswagen', 'Vento', '1.2', 'TSI', 'Highline', 'AT']
# ['Mini', 'Cooper', 'Countryman', 'D']
# ['Volvo', 'S60', 'D4', 'KINETIC']
# ['Renault', 'Pulse', 'RxL']
# ['Honda', 'Amaze', 'SX', 'i-VTEC']
# ['Toyota', 'Camry', '2.5', 'G']
# ['Maruti', 'Alto', 'LXi']
# ['Skoda', 'Superb', 'Style', '1.8', 'TSI', 'AT']
# ['Maruti', 'Ertiga', 'ZXI']
# ['Audi', 'A4', '2.0', 'TDI']
# ['Maruti', 'Ertiga', 'VDI']
# ['Mercedes-Benz', 'New', 'C-Class', 'C', '220', 'CDI', 'Style']
# ['Maruti', 'Swift', 'Dzire', '1.2', 'Vxi', 'BSIV']
# ['Mercedes-Benz', 'GLA', 'Class', '200', 'CDI', 'SPORT']
# ['Honda', 'City', 'i', 'VTEC', 'VX', 'Option']
# ['Maruti', 'Alto', 'LXi', 'BSII']
# ['Toyota', 'Fortuner', '3.0', 'Diesel']
# ['BMW', '3', 'Series', 'Luxury', 'Line']
# ['Hyundai', 'Elite', 'i20', 'Petrol', 'Asta']
# ['Honda', 'Amaze', 'VX', 'i-DTEC']
# ['Volkswagen', 'Jetta', '2007-2011', '2.0', 'TDI', 'Comfortline']
# ['Mercedes-Benz', 'S', 'Class', '2005', '2013', '320', 'L']
# ['Hyundai', 'EON', 'Era']
# ['Maruti', 'Zen', 'Estilo', 'LXI', 'BSIII']
# ['Hyundai', 'Verna', 'CRDi', 'SX']
# ['Hyundai', 'Verna', 'VTVT', '1.6', 'AT', 'SX', 'Option']
# ['Hyundai', 'i20', 'Asta', 'Option', '1.2']
# ['Maruti', 'Baleno', 'Vxi', '-', 'BSIII']
# ['Honda', 'Jazz', '1.5', 'S', 'i', 'DTEC']
# ['Volkswagen', 'Vento', 'Diesel', 'Comfortline']
# ['Hyundai', 'i10', 'Magna', '1.1L']
# ['Jeep', 'Compass', '2.0', 'Sport']
# ['Renault', 'Duster', '110PS', 'Diesel', 'RxZ']
# ['Maruti', 'Swift', 'Dzire', 'VXi']
# ['Maruti', 'Alto', 'LXi']
# ['Tata', 'Nano', 'XTA']
# ['Hyundai', 'i10', 'Era', '1.1']
# ['Maruti', 'Alto', 'XCITE']
# ['Ford', 'Figo', 'Diesel', 'EXI']
# ['Land', 'Rover', 'Discovery', '4', 'TDV6', 'Auto', 'Diesel']
# ['Honda', 'City', 'i', 'DTec', 'SV']
# ['Maruti', 'Ritz', 'LDi']
# ['Hyundai', 'Grand', 'i10', '1.2', 'Kappa', 'Sportz', 'Option']
# ['Hyundai', 'Grand', 'i10', 'AT', 'Asta']
# ['Hyundai', 'i20', 'Sportz', 'Option', '1.2']
# ['BMW', '5', 'Series', '2003-2012', '520d']
# ['Mercedes-Benz', 'E-Class', 'E250', 'CDI', 'Avantgrade']
# ['Toyota', 'Innova', '2.5', 'G', '(Diesel)', '7', 'Seater', 'BS', 'IV']
# ['Maruti', 'Swift', 'Dzire', 'ZDI']
# ['Maruti', 'Alto', 'K10', 'VXI']
# ['BMW', '5', 'Series', '520d', 'Luxury', 'Line']
# ['Maruti', 'Vitara', 'Brezza', 'VDi', 'Option']
# ['Hyundai', 'Verna', 'Transform', 'VTVT', 'with', 'Audio']
# ['Honda', 'City', 'i', 'VTEC', 'VX']
# ['Tata', 'Indica', 'Vista', 'Quadrajet', 'LS']
# ['Hyundai', 'i20', 'Active', '1.4', 'SX']
# ['Audi', 'A6', '2011-2015', '2.0', 'TDI']
# ['BMW', 'X5', 'xDrive', '30d', 'Design', 'Pure', 'Experience', '5', 'Seater']
# ['Hyundai', 'Creta', '1.6', 'SX', 'Plus', 'Dual', 'Tone', 'Petrol']
# ['Maruti', 'Vitara', 'Brezza', 'ZDi', 'Plus', 'AMT']
# ['Ford', 'Fiesta', '1.4', 'Duratec', 'EXI']
# ['Maruti', 'Dzire', 'AMT', 'VDI']
# ['Honda', 'City', 'i-VTEC', 'VX']
# ['Maruti', 'Celerio', 'VXI', 'AT']
# ['Chevrolet', 'Captiva', 'LT']
# ['Datsun', 'GO', 'T', 'Petrol']
# ['Skoda', 'Superb', 'Petrol', 'Ambition']
# ['Hyundai', 'Santro', 'Xing', 'GL']
# ['Mahindra', 'Renault', 'Logan', '1.5', 'DLE', 'Diesel']
# ['Tata', 'Tiago', '1.05', 'Revotorq', 'XT', 'Option']
# ['Volkswagen', 'Vento', 'Petrol', 'Highline', 'AT']
# ['Hyundai', 'i20', '1.2', 'Spotz']
# ['Ford', 'EcoSport', '1.5', 'Petrol', 'Ambiente']
# ['Jeep', 'Compass', '1.4', 'Sport']
# ['Audi', 'A4', '2.0', 'TDI']
# ['Hyundai', 'Verna', '1.6', 'SX', 'VTVT', '(O)']
# ['Maruti', 'Vitara', 'Brezza', 'ZDi']
# ['Hyundai', 'Elite', 'i20', 'Magna', 'Plus']
# ['Honda', 'Amaze', 'S', 'i-Dtech']
# ['Audi', 'A4', '2.0', 'TDI']
# ['Honda', 'Amaze', 'VX', 'AT', 'i-Vtech']
# ['Honda', 'Jazz', '1.5', 'V', 'i', 'DTEC']
# ['BMW', '5', 'Series', '525d', 'Sedan']
# ['Hyundai', 'Grand', 'i10', 'Asta', 'Option']
# ['Renault', 'Duster', '85PS', 'Diesel', 'RxL']
# ['Chevrolet', 'Aveo', '1.4', 'LS']
# ['Honda', 'Amaze', 'S', 'i-Vtech']
# ['Hyundai', 'Grand', 'i10', 'AT', 'Asta']
# ['Hyundai', 'EON', 'D', 'Lite', 'Plus']
# ['Volkswagen', 'Vento', 'Diesel', 'Trendline']
# ['Volkswagen', 'Polo', 'GT', 'TSI']
# ['Nissan', 'Micra', 'Diesel', 'XV']
# ['Volkswagen', 'Polo', 'GT', 'TSI']
# ['Mercedes-Benz', 'E-Class', '2009-2013', 'E', '220', 'CDI', 'Avantgarde']

# %%
len(Models)
# Out:
# 35093

# %%
from collections import Counter

# %%
probabale_model_name = []
for i in Counter(Models).most_common(30):
    probabale_model_name.append(i[0])

# %%
probabale_model_name
trimmed_list = ['Maruti','Hyundai','Honda','Toyota','Mercedes-Benz',
               'Volkswagen','Ford','Mahindra','BMW','Audi','Tata','Nissan','Rover',
               'Datsun','Chevrolet','Skoda','Fiat','Cooper','Jaguar',
               'Mitsubishi','Porsche','Ambassador','Renault','Volvo','Jeep',
               'Bentley','Lamborghini','ISUZU','Force']

# %%
for i in raw_data['Name'].values:
    ii = i.split(" ") 
    #print(i)
    #print(ii)
    tmp_list = [j for j in trimmed_list if j not in ii]
    #print(tmp_list)
    if(len(tmp_list) == 29):
        print(ii)
    #break
# Out:
# ['Smart', 'Fortwo', 'CDI', 'AT']
# ['Isuzu', 'MUX', '4WD']
# Tata
# Volkswagen
# Hyundai
# Ford
# Jeep
# Audi
# Hyundai
# Maruti
# Hyundai
# Honda
# Audi
# Honda
# Honda
# BMW
# Hyundai
# Renault
# Chevrolet
# Honda
# Hyundai
# Hyundai
# Volkswagen
# Volkswagen
# Nissan
# Volkswagen
# Mercedes-Benz

# %%
raw_data['Car_Brands'] = Car_Brand_Name

# %%
pandas_profiling.ProfileReport(raw_data[['Car_Brands']])
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>7253 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>56.7 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>8.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li>Dataset has 7223 duplicate rows <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Car_Brands">Car_Brands<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="">
#             <th>Distinct count</th>
#             <td>30</td>
#         </tr>
#         <tr>
#             <th>Unique (%)</th>
#             <td>0.4%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (%)</th>
#             <td>0.0%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (n)</th>
#             <td>0</td>
#         </tr>
#     </table>
# </div>
# <div class="col-md-6 collapse in" id="minifreqtable1704804591041073788">
#     <table class="mini freq">
#         <tr class="">
#     <th>Maruti</th>
#     <td>
#         <div class="bar" style="width:39%" data-toggle="tooltip" data-placement="right" data-html="true"
#              data-delay=500 title="Percentage: 19.9%">
#             1444
#         </div>
#
#     </td>
# </tr><tr class="">
#     <

# %%
raw_data.drop(['New_Price'], axis=1, inplace=True)

# %%
raw_data.columns
# Out:
# Index(['Engine', 'Fuel_Type', 'Kilometers_Driven', 'Location', 'Mileage',
#        'Name', 'Owner_Type', 'Power', 'Price', 'Seats', 'Transmission', 'Year',
#        'source', 'Car_Brands'],
#       dtype='object')

# %%
raw_data=raw_data[['Engine', 'Fuel_Type', 'Kilometers_Driven', 'Location', 'Mileage','Car_Brands',
       'Name', 'Owner_Type', 'Power', 'Seats', 'Transmission', 'Year',
       'source' , 'Price']]

# %%
raw_data
# Out:
#        Engine Fuel_Type  Kilometers_Driven    Location  Mileage  \
# 0      998 CC       CNG              72000      Mumbai    26.60
# 1     1582 CC    Diesel              41000        Pune    19.67
# 2     1199 CC    Petrol              46000     Chennai    18.20
# 3     1248 CC    Diesel              87000     Chennai    20.77
# 4     1968 CC    Diesel              40670  Coimbatore    15.20
# 5      814 CC       LPG              75000   Hyderabad    21.10
# 6     1461 CC    Diesel              86999      Jaipur    23.08
# 7     2755 CC    Diesel              36000      Mumbai    11.36
# 8     1598 CC    Diesel              64430        Pune    20.54
# 9     1248 CC    Diesel              65932     Chennai    22.30
# 10    1462 CC    Petrol              25692       Kochi    21.56
# 11    1497 CC    Petrol              60000     Kolkata    16.80
# 12    1248 CC    Diesel              64424      Jaipur    25.20
# 13    2179 CC    Diesel              72000       Delhi    12.70
# 14    2179 CC    Diesel              85000        Pune     0.00
# 15    2477 CC    Diesel             110000       Delhi    13.50
# 16    1498 CC    Diesel              58950       Kochi    25.80
# 17    1248 CC    Diesel              25000      Jaipur    28.40
# 18    1461 CC    Diesel              77469       Kochi    20.45
# 19    2143 CC    Diesel              78500   Bangalore    14.84
# 7              First  171.50    8.0    Automatic  2016  train  17.50
# 8              First  103.60    5.0       Manual  2013  train   5.20
# 9             Second   74.00    5.0       Manual  2012  train   1.95
# 10             First  103.25    5.0       Manual  2018  train   9.95
# 11             First  116.30    5.0    Automatic  2012  train   4.49
# 12             First   74.00    5.0       Manual  2015  train   5.60
# 13             First  187.70    5.0    Automatic  2014  train  27.00
# 14            Second  115.00    5.0    Automatic  2012  train  17.50
# 15             First  175.56    7.0       Manual  2014  train  15.00
# 16             First   98.60    5.0       Manual  2016  train   5.40
# 17             First   74.00    5.0       Manual  2017  train   5.99
# 18             First   83.80    5.0       Manual  2014  train   6.34
# 19             First  167.62    5.0    Automatic  2014  train  28.00
# 20             First  190.00    5.0    Automatic  2014  train  18.55
# 21            Second   88.50    5.0       Manual  2015  train   8.25
# 22             First  177.01    5.0    Automatic  2015  train  23.50
# 23             First   80.00    5.0       Manual  2010  train   1.87
# 24             First  103.60    5.0    Automatic  2010  train   2.85
# 25             First  116.30    5.0       Manual  2012  train   4.25
# 26             First   63.10    5.0       Manual  2012  train   4.25
# 27            Second   67.10    5.0       Manual  2013  train   2.75
# 28             First   88.70    5.0       Manual  2018  train   9.90
# 29    Fourth & Above  102.00    7.0       Manual  2007  train   4.00
# ...              ...     ...    ...          ...   ...    ...    ...
# 7223           First  147.90    7.0       Manual  2011   test    NaN
# 7224           First   67.00    5.0       Manual  2016   test    NaN
# 7225           First  157.80    5.0       Manual  2010   test    NaN
# 7226           First   62.00    5.0       Manual  2014   test    NaN
# 7227          Second   65.00    5.0       Manual  2007   test    NaN
# 7228           First   69.00    5.0       Manual  2016   test    NaN
# 7229          Second  103.60    5.0    Automatic  2011   test    NaN
# 7230           First   81.83    5.0       Manual  2014   test    NaN
# 7231           First  121.36    5.0       Manual  2017   test    NaN
# 7232           First  160.00    5.0       Manual  2018   test    NaN
# 7233           First  147.51    5.0    Automatic  2014   test    NaN
# 7234           First  121.30    5.0       Manual  2013   test    NaN
# 7235           First   88.50    5.0       Manual  2017   test    NaN
# 7236           First   81.86    5.0       Manual  2018   test    NaN
# 7237           First   98.60    5.0       Manual  2013   test    NaN
# 7238           First  147.51    5.0    Automatic  2011   test    NaN
# 7239           First   86.70    5.0    Automatic  2014   test    NaN
# 7240           First   98.60    5.0       Manual  2017   test    NaN
# 7241           First  218.00    5.0    Automatic  2012   test    NaN
# 7242           First   82.00    5.0       Manual  2015   test    NaN
# 7243           First   83.80    5.0       Manual  2015   test    NaN
# 7244           First   92.70    5.0       Manual  2009   test    NaN
# 7245           First   86.70    5.0       Manual  2015   test    NaN
# 7246           First   82.00    5.0    Automatic  2016   test    NaN
# 7247           First   55.20    5.0       Manual  2015   test    NaN
# 7248           First  103.60    5.0       Manual  2011   test    NaN
# 7249           First  103.60    5.0    Automatic  2015   test    NaN
# 7250           First   63.10    5.0       Manual  2012   test    NaN
# 7251           Third  103.60    5.0    Automatic  2013   test    NaN
# 7252           First  170.00    5.0    Automatic  2014   test    NaN
#
# [7253 rows x 14 columns]
